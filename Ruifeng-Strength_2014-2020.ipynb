# %%
# import packages
import csv
import pandas as pd
import numpy as np
import os
import nltk
import re
from nltk import word_tokenize

# %%
df_B = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/2014-B-EMPFreeResponse.csv")
df_B.head()
# Out:
#    Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0              6  201435-201445          SR            B       ACCT  4COP
# 1             11  201415-201425          JR            B        FIN  4COP
# 2             25  201435-201445          JR            B       GBUS  4COP
# 3             37  201435-201445          SR            B       LGST  5COP
# 4             44  201435-201445          SO            B        BAE  5COP
#
#   Major Conc Co-op # Citizenship Status  \
# 0        NaN    Only         US Citizen
# 1        NaN    Only         US Citizen
# 2        NaN    Only         US Citizen
# 3        NaN  Second         US Citizen
# 4        NaN   First         US Citizen
#
#                    What are the student's strengths?
# 0  [Student's] strengths include the ability to m...
# 1  Demonstrates knowledge in compiling and analyz...
# 2  [Student] is detail-oriented, customer-focused...
# 3  Excellent attention to detail and work ethic. ...
# 4  Communication skills, leadership, lead by example

# %%
# Copy the 'Strengths' Columm
df_B.rename(columns = {"What are the student's strengths?":'Strengths'}, inplace = True)
df_B
# Out:
#      Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0                6  201435-201445          SR            B       ACCT  4COP
# 1               11  201415-201425          JR            B        FIN  4COP
# 2               25  201435-201445          JR            B       GBUS  4COP
# 3               37  201435-201445          SR            B       LGST  5COP
# 4               44  201435-201445          SO            B        BAE  5COP
# ..             ...            ...         ...          ...        ...   ...
# 728           5918  201435-201445          JR            B       GBUS  4COP
# 729           5920  201435-201445          JR            B       GBUS  4COP
# 730           5921  201435-201445          JR            B       GBUS  4COP
# 731           5932  201435-201445          JR            B       GBUS  4COP
# 732           5939  201435-201445          JR            B       ACCT  5COP
#
#     Major Conc Co-op # Citizenship Status  \
# 0          NaN    Only         US Citizen
# 1          NaN    Only         US Citizen
# 2          NaN    Only         US Citizen
# 3          NaN  Second         US Citizen
# 4          NaN   First         US Citizen
# ..         ...     ...                ...
# 728        NaN    Only         US Citizen
# 729        NaN    Only         US Citizen
# 730        NaN    Only         US Citizen
# 731        NaN    Only         US Citizen
# 732        NaN   First         US Citizen
#
#                                              Strengths
# 0    [Student's] strengths include the ability to m...
# 1    Demonstrates knowledge in compiling and analyz...
# 2    [Student] is detail-oriented, customer-focused...
# 3    Excellent attention to detail and work ethic. ...
# 4    Communication skills, leadership, lead by example
# ..                                                 ...
# 728  He became our go to person and team lead for p...
# 729  [Student] was THE FIRST to let all know if she...
# 730  [Student] has great organizational skills, she...
# 731  [Student] is great with teamwork. He has a wil...
# 732  [Student] has been a pleasure to have working ...
#
# [733 rows x 10 columns]

# %%
# import another file
df_BE = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/2014-BE-EMPFreeResponse.csv")

# %%
df_BE.head()
# Out:
#    Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0             17  201435-201445          SR           BE       ECON  4COP
# 1            174  201435-201445          SR           BE       ECON  5COP
# 2            363  201435-201445          JR           BE       ECON  5COP
# 3            384  201435-201445          SR           BE       ECON  5COP
# 4            548  201435-201445          JR           BE       ECON  5COP
#
#   Major Conc Co-op #          Citizenship Status  \
# 0        NaN    Only                  US Citizen
# 1        NaN  Second  Resident Alien Non-Citizen
# 2       MAEC  Second  Resident Alien Non-Citizen
# 3        NaN  Second                  US Citizen
# 4       MAEC   First                  US Citizen
#
#                    What are the student's strengths?
# 0  Student was very efficient and excellent as it...
# 1  [Student] is a really hard worker.  [Student's...
# 2  [Student's] greatest strengths are her desire ...
# 3  [Student] possesses a terrific attitude, work ...
# 4  Team player, Initiative, Leadership, Communica...

# %%
# Rename the 'Strengths' Columm
df_BE.rename(columns = {"What are the student's strengths?":'Strengths'}, inplace = True)

# %%
# Merged two files
df_contact = pd.concat([df_B, df_BE], axis = 0)
# df_merge = df_B + df_BE

# %%
# Check if contact successfully
df_contact
# Out:
#     Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0               6  201435-201445          SR            B       ACCT  4COP
# 1              11  201415-201425          JR            B        FIN  4COP
# 2              25  201435-201445          JR            B       GBUS  4COP
# 3              37  201435-201445          SR            B       LGST  5COP
# 4              44  201435-201445          SO            B        BAE  5COP
# ..            ...            ...         ...          ...        ...   ...
# 39           5033  201435-201445          SR           BE       ECON  5COP
# 40           5057  201435-201445          SR           BE       ECON  5COP
# 41           5410  201435-201445          SR           BE       ECON  5COP
# 42           5736  201435-201445          SR           BE       ECON  5COP
# 43           5944  201435-201445          PJ           BE       ECON  5COP
#
#    Major Conc Co-op # Citizenship Status  \
# 0         NaN    Only         US Citizen
# 1         NaN    Only         US Citizen
# 2         NaN    Only         US Citizen
# 3         NaN  Second         US Citizen
# 4         NaN   First         US Citizen
# ..        ...     ...                ...
# 39        NaN   Third         US Citizen
# 40       BSEC   Third         US Citizen
# 41        NaN   Third         US Citizen
# 42        NaN   Third         US Citizen
# 43        NaN  Second         US Citizen
#
#                                             Strengths
# 0   [Student's] strengths include the ability to m...
# 1   Demonstrates knowledge in compiling and analyz...
# 2   [Student] is detail-oriented, customer-focused...
# 3   Excellent attention to detail and work ethic. ...
# 4   Communication skills, leadership, lead by example
# ..                                                ...
# 39  [Student] has been an incredible help and cont...
# 40  [Student] is self-motivated, a quick learner t...
# 41  Independent. Quickly learns and understands co...
# 42  Ability to accomplish complex tasks with minim...
# 43  Detailed focused, willingness to learn, listen...
#
# [777 rows x 10 columns]

# %%
# Reset the index
df_contact.reset_index(inplace = True, drop = True)
df_contact
# Out:
#      Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0                6  201435-201445          SR            B       ACCT  4COP
# 1               11  201415-201425          JR            B        FIN  4COP
# 2               25  201435-201445          JR            B       GBUS  4COP
# 3               37  201435-201445          SR            B       LGST  5COP
# 4               44  201435-201445          SO            B        BAE  5COP
# ..             ...            ...         ...          ...        ...   ...
# 772           5033  201435-201445          SR           BE       ECON  5COP
# 773           5057  201435-201445          SR           BE       ECON  5COP
# 774           5410  201435-201445          SR           BE       ECON  5COP
# 775           5736  201435-201445          SR           BE       ECON  5COP
# 776           5944  201435-201445          PJ           BE       ECON  5COP
#
#     Major Conc Co-op # Citizenship Status  \
# 0          NaN    Only         US Citizen
# 1          NaN    Only         US Citizen
# 2          NaN    Only         US Citizen
# 3          NaN  Second         US Citizen
# 4          NaN   First         US Citizen
# ..         ...     ...                ...
# 772        NaN   Third         US Citizen
# 773       BSEC   Third         US Citizen
# 774        NaN   Third         US Citizen
# 775        NaN   Third         US Citizen
# 776        NaN  Second         US Citizen
#
#                                              Strengths
# 0    [Student's] strengths include the ability to m...
# 1    Demonstrates knowledge in compiling and analyz...
# 2    [Student] is detail-oriented, customer-focused...
# 3    Excellent attention to detail and work ethic. ...
# 4    Communication skills, leadership, lead by example
# ..                                                 ...
# 772  [Student] has been an incredible help and cont...
# 773  [Student] is self-motivated, a quick learner t...
# 774  Independent. Quickly learns and understands co...
# 775  Ability to accomplish complex tasks with minim...
# 776  Detailed focused, willingness to learn, listen...
#
# [777 rows x 10 columns]

# %%
# Check the duplicated
df_contact.duplicated().sum()
# Out:
# 0

# %%
df_contact.isnull().sum()
# Out:
# Respondent ID           0
# Terms                   0
# Class (BOT)             0
# College Code            0
# Major Code              0
# Conc                    0
# Major Conc            754
# Co-op #                 0
# Citizenship Status      0
# Strengths               5
# dtype: int64

# %%
from nltk.corpus import stopwords
import string
# from nltk.stem.porter import PorterStemmer
# ps = PorterStemmer()

# %%
# Convert Column Value to string
df_contact[['Strengths']] = df_contact[['Strengths']].astype(str)

# %%
# Remove Punctuations
def remove_punctuations(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# %%
# dataframe
df_contact['Strengths'] = df_contact['Strengths'].apply(lambda x: remove_punctuations(x))
df_contact
# Out:
#      Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0                6  201435-201445          SR            B       ACCT  4COP
# 1               11  201415-201425          JR            B        FIN  4COP
# 2               25  201435-201445          JR            B       GBUS  4COP
# 3               37  201435-201445          SR            B       LGST  5COP
# 4               44  201435-201445          SO            B        BAE  5COP
# ..             ...            ...         ...          ...        ...   ...
# 772           5033  201435-201445          SR           BE       ECON  5COP
# 773           5057  201435-201445          SR           BE       ECON  5COP
# 774           5410  201435-201445          SR           BE       ECON  5COP
# 775           5736  201435-201445          SR           BE       ECON  5COP
# 776           5944  201435-201445          PJ           BE       ECON  5COP
#
#     Major Conc Co-op # Citizenship Status  \
# 0          NaN    Only         US Citizen
# 1          NaN    Only         US Citizen
# 2          NaN    Only         US Citizen
# 3          NaN  Second         US Citizen
# 4          NaN   First         US Citizen
# ..         ...     ...                ...
# 772        NaN   Third         US Citizen
# 773       BSEC   Third         US Citizen
# 774        NaN   Third         US Citizen
# 775        NaN   Third         US Citizen
# 776        NaN  Second         US Citizen
#
#                                              Strengths
# 0    Students strengths include the ability to mana...
# 1    Demonstrates knowledge in compiling and analyz...
# 2    Student is detailoriented customerfocused and ...
# 3    Excellent attention to detail and work ethic Q...
# 4      Communication skills leadership lead by example
# ..                                                 ...
# 772  Student has been an incredible help and contri...
# 773  Student is selfmotivated a quick learner that ...
# 774  Independent Quickly learns and understands com...
# 775  Ability to accomplish complex tasks with minim...
# 776  Detailed focused willingness to learn listens ...
#
# [777 rows x 10 columns]

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Remove stopwords
from nltk.corpus import stopwords

# %%
STOPWORDS = set(stopwords.words('english'))

# %%
# It has been modifies this time
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

# %%
df_contact['Strengths'] = df_contact['Strengths'].apply(lambda x: remove_stopwords(x))
df_contact
# Out:
#      Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0                6  201435-201445          SR            B       ACCT  4COP
# 1               11  201415-201425          JR            B        FIN  4COP
# 2               25  201435-201445          JR            B       GBUS  4COP
# 3               37  201435-201445          SR            B       LGST  5COP
# 4               44  201435-201445          SO            B        BAE  5COP
# ..             ...            ...         ...          ...        ...   ...
# 772           5033  201435-201445          SR           BE       ECON  5COP
# 773           5057  201435-201445          SR           BE       ECON  5COP
# 774           5410  201435-201445          SR           BE       ECON  5COP
# 775           5736  201435-201445          SR           BE       ECON  5COP
# 776           5944  201435-201445          PJ           BE       ECON  5COP
#
#     Major Conc Co-op # Citizenship Status  \
# 0          NaN    Only         US Citizen
# 1          NaN    Only         US Citizen
# 2          NaN    Only         US Citizen
# 3          NaN  Second         US Citizen
# 4          NaN   First         US Citizen
# ..         ...     ...                ...
# 772        NaN   Third         US Citizen
# 773       BSEC   Third         US Citizen
# 774        NaN   Third         US Citizen
# 775        NaN   Third         US Citizen
# 776        NaN  Second         US Citizen
#
#                                              Strengths
# 0    Students strengths include ability manage time...
# 1    Demonstrates knowledge compiling analyzing com...
# 2    Student detailoriented customerfocused works w...
# 3    Excellent attention detail work ethic Quick le...
# 4         Communication skills leadership lead example
# ..                                                 ...
# 772  Student incredible help contributor team past ...
# 773  Student selfmotivated quick learner needs mini...
# 774  Independent Quickly learns understands company...
# 775  Ability accomplish complex tasks minimal defin...
# 776    Detailed focused willingness learn listens well
#
# [777 rows x 10 columns]

# %%
# d1['Strengths'] = d1['Strengths'].astype('str')
df_contact['Strengths'] = df_contact['Strengths'].str.lower()
## Experiment Record: 
# org_project.columns=org_project.columns.map(lambda x:x.lower())
# new_df_copy = df.loc[df.col1>2].copy()
# new_df_copy.loc[2, 'new_column'] = 100
# Codes with # cannot work well however only worked code result in SettingWithCopyWarning:

# %%
# Lemmatization Package Download
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\37605\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Implementing Lemmatization: Input and Assignment
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()
# Reference: https://www.jianshu.com/p/a4c878412c49
print(type(df_contact['Strengths']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# try to tokenize in input raw
def word_tokens(text):
      Token = word_tokenize(text)
      return Token

# %%
# Try to tokenize the ['Strengths'] again
df_contact['Strengths_tokens'] = df_contact['Strengths'].apply(lambda x: word_tokens(x))

# %%
# Try to lemmatize again
wnl = nltk.WordNetLemmatizer()

# %%
def Wnlemm(s):
    words = [wnl.lemmatize(r) for r in s]
    return words

# %%
df_contact['Strengths_lem'] = df_contact['Strengths_tokens'].apply(lambda x: Wnlemm(x))

# %%
df_contact.head()
# Bingo!
# Reference: Yamini's code
# Out:
#    Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0              6  201435-201445          SR            B       ACCT  4COP
# 1             11  201415-201425          JR            B        FIN  4COP
# 2             25  201435-201445          JR            B       GBUS  4COP
# 3             37  201435-201445          SR            B       LGST  5COP
# 4             44  201435-201445          SO            B        BAE  5COP
#
#   Major Conc Co-op # Citizenship Status  \
# 0        NaN    Only         US Citizen
# 1        NaN    Only         US Citizen
# 2        NaN    Only         US Citizen
# 3        NaN  Second         US Citizen
# 4        NaN   First         US Citizen
#
#                                            Strengths  \
# 0  students strengths include ability manage time...
# 1  demonstrates knowledge compiling analyzing com...
# 2  student detailoriented customerfocused works w...
# 3  excellent attention detail work ethic quick le...
# 4       communication skills leadership lead example
#
#                                     Strengths_tokens  \
# 0  [students, strengths, include, ability, manage...
# 1  [demonstrates, knowledge, compiling, analyzing...
# 2  [student, detailoriented, customerfocused, wor...
# 3  [excellent, attention, detail, work, ethic, qu...
# 4  [communication, skills, leadership, lead, exam...
#
#                                        Strengths_lem
# 0  [student, strength, include, ability, manage, ...
# 1  [demonstrates, knowledge, compiling, analyzing...
# 2  [student, detailoriented, customerfocused, wor...
# 3  [excellent, attention, detail, work, ethic, qu...
# 4  [communication, skill, leadership, lead, example]

# %%
# Setting some words that not useful to analyze
Uword = ['student', 'able', 'never', 'work', 'task', 'project', 'include', 'strength', 'very', 'good', 'always', 'great', 'well', 'excellent', 'other', 'also', 'coop', 'working', 'i', 'he', 'she', 'his', 'her', 'him', 'me', "'", 's']

# %%
# Remove these unuseful words
# def remove_Uword(text):
#     return ", ".join([word for word in text if word not in Uword])
def remove_Uword(text):
     return ", ".join([word for word in text if word not in Uword])

# %%
df_contact['Strengths_U'] = df_contact['Strengths_lem'].apply(lambda x: remove_Uword(x))

# %%
# Check if remove unuseful words succesfully
df_contact.head()
print(type(df_contact['Strengths_U']))
# But it seems to ['Strengths_U'] never be tokenized...
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Try to make a copy of df_contact, I will have an experiment of further analysis later
import copy

# %%
df_preproce = copy.deepcopy(df_contact)
df_preproce
# Out:
#      Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0                6  201435-201445          SR            B       ACCT  4COP
# 1               11  201415-201425          JR            B        FIN  4COP
# 2               25  201435-201445          JR            B       GBUS  4COP
# 3               37  201435-201445          SR            B       LGST  5COP
# 4               44  201435-201445          SO            B        BAE  5COP
# ..             ...            ...         ...          ...        ...   ...
# 772           5033  201435-201445          SR           BE       ECON  5COP
# 773           5057  201435-201445          SR           BE       ECON  5COP
# 774           5410  201435-201445          SR           BE       ECON  5COP
# 775           5736  201435-201445          SR           BE       ECON  5COP
# 776           5944  201435-201445          PJ           BE       ECON  5COP
#
#     Major Conc Co-op # Citizenship Status  \
# 0          NaN    Only         US Citizen
# 1          NaN    Only         US Citizen
# 2          NaN    Only         US Citizen
# 3          NaN  Second         US Citizen
# 4          NaN   First         US Citizen
# ..         ...     ...                ...
# 772        NaN   Third         US Citizen
# 773       BSEC   Third         US Citizen
# 774        NaN   Third         US Citizen
# 775        NaN   Third         US Citizen
# 776        NaN  Second         US Citizen
#
#                                              Strengths  \
# 0    students strengths include ability manage time...
# 1    demonstrates knowledge compiling analyzing com...
# 2    student detailoriented customerfocused works w...
# 3    excellent attention detail work ethic quick le...
# 4         communication skills leadership lead example
# ..                                                 ...
# 772  student incredible help contributor team past ...
# 773  student selfmotivated quick learner needs mini...
# 774  independent quickly learns understands company...
# 775  ability accomplish complex tasks minimal defin...
# 776    detailed focused willingness learn listens well
#
#                                       Strengths_tokens  \
# 0    [students, strengths, include, ability, manage...
# 1    [demonstrates, knowledge, compiling, analyzing...
# 2    [student, detailoriented, customerfocused, wor...
# 3    [excellent, attention, detail, work, ethic, qu...
# 4    [communication, skills, leadership, lead, exam...
# ..                                                 ...
# 772  [student, incredible, help, contributor, team,...
# 773  [student, selfmotivated, quick, learner, needs...
# 774  [independent, quickly, learns, understands, co...
# 775  [ability, accomplish, complex, tasks, minimal,...
# 776  [detailed, focused, willingness, learn, listen...
#
#                                          Strengths_lem  \
# 0    [student, strength, include, ability, manage, ...
# 1    [demonstrates, knowledge, compiling, analyzing...
# 2    [student, detailoriented, customerfocused, wor...
# 3    [excellent, attention, detail, work, ethic, qu...
# 4    [communication, skill, leadership, lead, example]
# ..                                                 ...
# 772  [student, incredible, help, contributor, team,...
# 773  [student, selfmotivated, quick, learner, need,...
# 774  [independent, quickly, learns, understands, co...
# 775  [ability, accomplish, complex, task, minimal, ...
# 776  [detailed, focused, willingness, learn, listen...
#
#                                            Strengths_U
# 0    ability, manage, time, complete, daily, assign...
# 1    demonstrates, knowledge, compiling, analyzing,...
# 2    detailoriented, customerfocused, team, environ...
# 3    attention, detail, ethic, quick, learner, show...
# 4      communication, skill, leadership, lead, example
# ..                                                 ...
# 772  incredible, help, contributor, team, past, 6, ...
# 773  selfmotivated, quick, learner, need, minimal, ...
# 774  independent, quickly, learns, understands, com...
# 775  ability, accomplish, complex, minimal, definit...
# 776     detailed, focused, willingness, learn, listens
#
# [777 rows x 13 columns]

# %%
df_preproce = df_preproce.drop(['Strengths', 'Strengths_tokens', 'Strengths_lem'], axis = 1)

# %%
## Until Nov25 0:56am, I had finished almost all necessary steps in preprocessing, I will compare the difference between ['Strengths_U'] and ['Strengths_U'] tomorrow.

# %%
df_contact.head()
# Out:
#    Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0              6  201435-201445          SR            B       ACCT  4COP
# 1             11  201415-201425          JR            B        FIN  4COP
# 2             25  201435-201445          JR            B       GBUS  4COP
# 3             37  201435-201445          SR            B       LGST  5COP
# 4             44  201435-201445          SO            B        BAE  5COP
#
#   Major Conc Co-op # Citizenship Status  \
# 0        NaN    Only         US Citizen
# 1        NaN    Only         US Citizen
# 2        NaN    Only         US Citizen
# 3        NaN  Second         US Citizen
# 4        NaN   First         US Citizen
#
#                                            Strengths  \
# 0  students strengths include ability manage time...
# 1  demonstrates knowledge compiling analyzing com...
# 2  student detailoriented customerfocused works w...
# 3  excellent attention detail work ethic quick le...
# 4       communication skills leadership lead example
#
#                                     Strengths_tokens  \
# 0  [students, strengths, include, ability, manage...
# 1  [demonstrates, knowledge, compiling, analyzing...
# 2  [student, detailoriented, customerfocused, wor...
# 3  [excellent, attention, detail, work, ethic, qu...
# 4  [communication, skills, leadership, lead, exam...
#
#                                        Strengths_lem  \
# 0  [student, strength, include, ability, manage, ...
# 1  [demonstrates, knowledge, compiling, analyzing...
# 2  [student, detailoriented, customerfocused, wor...
# 3  [excellent, attention, detail, work, ethic, qu...
# 4  [communication, skill, leadership, lead, example]
#
#                                          Strengths_U
# 0  ability, manage, time, complete, daily, assign...
# 1  demonstrates, knowledge, compiling, analyzing,...
# 2  detailoriented, customerfocused, team, environ...
# 3  attention, detail, ethic, quick, learner, show...
# 4    communication, skill, leadership, lead, example

# %%
df_preproce.head()
# Out:
#    Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 0              6  201435-201445          SR            B       ACCT  4COP
# 1             11  201415-201425          JR            B        FIN  4COP
# 2             25  201435-201445          JR            B       GBUS  4COP
# 3             37  201435-201445          SR            B       LGST  5COP
# 4             44  201435-201445          SO            B        BAE  5COP
#
#   Major Conc Co-op # Citizenship Status  \
# 0        NaN    Only         US Citizen
# 1        NaN    Only         US Citizen
# 2        NaN    Only         US Citizen
# 3        NaN  Second         US Citizen
# 4        NaN   First         US Citizen
#
#                                          Strengths_U
# 0  ability, manage, time, complete, daily, assign...
# 1  demonstrates, knowledge, compiling, analyzing,...
# 2  detailoriented, customerfocused, team, environ...
# 3  attention, detail, ethic, quick, learner, show...
# 4    communication, skill, leadership, lead, example

# %%
# https://stackoverflow.com/questions/8270092/remove-all-whitespace-in-a-string
# df_preproce['Strengths_U2'] = df_preproce['Strengths_U'].replace('','')
# df_preproce['Strengths_U2'] = re.sub(r"^\s+", "", df_preproce['Strengths_U'], flags=re.UNICODE)

# %%
df_preproce.tail()
# Out:
#      Respondent ID          Terms Class (BOT) College Code Major Code  Conc  \
# 772           5033  201435-201445          SR           BE       ECON  5COP
# 773           5057  201435-201445          SR           BE       ECON  5COP
# 774           5410  201435-201445          SR           BE       ECON  5COP
# 775           5736  201435-201445          SR           BE       ECON  5COP
# 776           5944  201435-201445          PJ           BE       ECON  5COP
#
#     Major Conc Co-op # Citizenship Status  \
# 772        NaN   Third         US Citizen
# 773       BSEC   Third         US Citizen
# 774        NaN   Third         US Citizen
# 775        NaN   Third         US Citizen
# 776        NaN  Second         US Citizen
#
#                                            Strengths_U
# 772  incredible, help, contributor, team, past, 6, ...
# 773  selfmotivated, quick, learner, need, minimal, ...
# 774  independent, quickly, learns, understands, com...
# 775  ability, accomplish, complex, minimal, definit...
# 776     detailed, focused, willingness, learn, listens

# %%
from collections import Counter
# freq_Strengths_U = Counter(df_preproce['Strengths_U'])
# freq_Strengths_U
# bow1 = Counter(df_14Strength)
# bow1
# dfV_14Strength = pd.DataFrame(bow1.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
# print(dfV_14Strength)
# # Reference: Yamini's code

# %%
len(df_preproce['Strengths_U'].sum())
# Out:
# 113232

# %%
df_14Strength = copy.deepcopy(df_preproce['Strengths_U'])
df_14Strength
# Out:
# 0      ability, manage, time, complete, daily, assign...
# 1      demonstrates, knowledge, compiling, analyzing,...
# 2      detailoriented, customerfocused, team, environ...
# 3      attention, detail, ethic, quick, learner, show...
# 4        communication, skill, leadership, lead, example
#                              ...
# 772    incredible, help, contributor, team, past, 6, ...
# 773    selfmotivated, quick, learner, need, minimal, ...
# 774    independent, quickly, learns, understands, com...
# 775    ability, accomplish, complex, minimal, definit...
# 776       detailed, focused, willingness, learn, listens
# Name: Strengths_U, Length: 777, dtype: object

# %%
type(df_14Strength)
# Out:
# pandas.core.series.Series

# %%
df_preproce['Strengths_U_2'] = df_preproce['Strengths_U'].apply(len)

# %%
len(df_preproce.Strengths_U.sum())
# Out:
# 113232

# %%
# Try to merge each unit of list
ag_strength = "".join(df_preproce['Strengths_U'])
# Reference: Yamini's code

# %%
words_strength = word_tokenize(ag_strength)

# %%
len(words_strength)
# Out:
# 24187

# %%
bow1 = Counter(words_strength)

# %%
# Try to remove ',' in python list
words_strength
for i in words_strength[:]:
    if i == ",":
        words_strength.remove(i)
# Reference: https://blog.csdn.net/weixin_44123630/article/details/110496150

# %%
bow_14Strength = Counter(words_strength)

# %%
df_14S_f = pd.DataFrame(bow_14Strength.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
df_14S_f
# Reference: Yamini's code
# Out:
#                        word  frequency
# 29                     team        180
# 11                    skill        152
# 2                      time        117
# 43                      new        105
# 42                    learn        104
# ...                     ...        ...
# 1831          detailsuccess          1
# 1830        skillattendance          1
# 603            streamlining          1
# 1828             aroundhard          1
# 3151  comprehensiondetailed          1
#
# [3152 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
Vsns_14S_f = sns.barplot(x = 'frequency', y = 'word', data = df_14S_f.head(20))
for i in Vsns_14S_f.containers:
    Vsns_14S_f.bar_label(i,)
Vsns_14S_f.set_title('2014 Strength Unigram', size = 18)
Vsns_14S_f.set_xlabel("Frequency", size = 15)
Vsns_14S_f.set_ylabel("Word(Bigram)", size = 15)
# Reference:
# [1] https://www.geeksforgeeks.org/how-to-show-values-on-seaborn-barplot/
# [2] https://www.geeksforgeeks.org/change-axis-labels-set-title-and-figure-size-to-plots-with-seaborn/
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
## Until Nov 26th 23:56, I had finished word frequency in unigram, I need add bigram and trigram later.

# %%
type(words_strength)
# Out:
# list

# %%
Strength_Uni = copy.deepcopy(words_strength)
type(Strength_Uni)
# Out:
# list

# %%
S_Unilist = ' '.join([str(item) for item in words_strength])

# %%
print(S_Unilist)
# Out:
# ability manage time complete daily assignment detail oriented extremely organized communication skill reliable individualdemonstrates knowledge compiling analyzing comparative report data skill creating chart graph superior knowledge using microsoft office applicationdetailoriented customerfocused team environmentattention detail ethic quick learner showed strong interest going way improve process willingness learn new thingcommunication skill leadership lead examplemajor passion completelythe ability identify issue bring issue attention ability easily male proceduredone job networking building professional relationship outside immediate team creative idea improving process receptive feedback asks question learn used within larger organization showing insight beyond scope current roledone lot audit involved the senior auditor transferred allowed john jump help involved within team want involved much possible attends intern event team eventdependable thoughtfuldemonstrated adaptability throughout positively dealing multiple change direct supervisor natured demeanor biggesthighly dependable provides consistent resultextremely reliable dependable punctual professional hard worker ambitious looking maintained highest standard valuable interndependable hardeagerness excitement take new challenge intellectual curiosity master newly introduced topic reach others seek additionalmotivatedtime management us time effictively get assigned accomplish compiling analyze data intimate knowledge microsoft excel othersexceptionally responsible volunteer jump help mundane challenging blend organized oriented style aforementioned sensitivity need whomever assigned compared past exemplified came personality superior product assisted business manager financial related report worked direction taxation assist tax filing numerous firm received positive feedback regard time employerdependable team player effective use current technologydemonstrated adaptability eager learn useful possible assigned variety marketingbusiness development completed efficiently hardworking proactive complete independentlyasset office minimum supervision communicates problemsaloni eager let team member know willing help duty that demonstrative team came offered create new drexel handbookto help next line know expected list resource procedure needresponsible intelligentcritical thinker analyze problem take ownership finding solution grasp relevant technology overall industry shy speaking various level colleague contact throughout organizationfocused value experience recognizes far taught much want postgraduation strong ethic desire learn anything everything really presentednatural team leader ton intiative reliable determined hard workerprofessional organizedstrong presentation skill communicatorconsistently balanced day independent collaboratively team exceeded deadline looked assignment looking challengedsocial interaction team demonstrates initiative area interest eg analysis finding audit issue logconscientous pleasurecommunication excel analytics job putting information reader spreadsheetasset team assigned difficult tax technical completed minimal help multitude different manage time appropriatelyknowledge excel willingness take projectstasks multitasking finding alternative solutionstrong driven demonstrated consistent aptitude solving problem achieving resultcommunication skill organization workspacecomplete assigned efficient manner seek solution various independentlyteam player willing take responsibilityquick learner commit deadline finish load given daily basis communication skill email conversationintelligent wellspoken problem solver quick learnhard extra hour completes time required maintains high quality imposes standard excellence without supervision followsdemonstrated attitude workplace worked hard experience willing put extra hour needed demonstrated ability pick thing quickly whether assignment company system willing whatever asked member groupcompany som ...

# %%
# Bigram and Trigram
from nltk import ngrams, bigrams, trigrams
from nltk.util import ngrams

def get_grams(text, n):
    n_grams = ngrams(word_tokenize(text), n)
    return [ ' '.join(grams) for grams in n_grams]
# Reference: https://stackoverflow.com/questions/17531684/n-grams-in-python-four-five-six-grams

# %%
S_Bilist = get_grams(S_Unilist, 2)
print(S_Bilist)
# Out:
# ['ability manage', 'manage time', 'time complete', 'complete daily', 'daily assignment', 'assignment detail', 'detail oriented', 'oriented extremely', 'extremely organized', 'organized communication', 'communication skill', 'skill reliable', 'reliable individualdemonstrates', 'individualdemonstrates knowledge', 'knowledge compiling', 'compiling analyzing', 'analyzing comparative', 'comparative report', 'report data', 'data skill', 'skill creating', 'creating chart', 'chart graph', 'graph superior', 'superior knowledge', 'knowledge using', 'using microsoft', 'microsoft office', 'office applicationdetailoriented', 'applicationdetailoriented customerfocused', 'customerfocused team', 'team environmentattention', 'environmentattention detail', 'detail ethic', 'ethic quick', 'quick learner', 'learner showed', 'showed strong', 'strong interest', 'interest going', 'going way', 'way improve', 'improve process', 'process willingness', 'willingness learn', 'learn new', 'new thingcommunication', 'thingcommunication skill', 'skill leadership', 'leadership lead', 'lead examplemajor', 'examplemajor passion', 'passion completelythe', 'completelythe ability', 'ability identify', 'identify issue', 'issue bring', 'bring issue', 'issue attention', 'attention ability', 'ability easily', 'easily male', 'male proceduredone', 'proceduredone job', 'job networking', 'networking building', 'building professional', 'professional relationship', 'relationship outside', 'outside immediate', 'immediate team', 'team creative', 'creative idea', 'idea improving', 'improving process', 'process receptive', 'receptive feedback', 'feedback asks', 'asks question', 'question learn', 'learn used', 'used within', 'within larger', 'larger organization', 'organization showing', 'showing insight', 'insight beyond', 'beyond scope', 'scope current', 'current roledone', 'roledone lot', 'lot audit', 'audit involved', 'involved the', 'the senior', 'senior auditor', 'auditor transferred', 'transferred allowed', 'allowed john', 'john jump', 'jump help', 'help involved', 'involved within', 'within team', 'team want', 'want involved', 'involved much', 'much possible', 'possible attends', 'attends intern', 'intern event', 'event team', 'team eventdependable', 'eventdependable thoughtfuldemonstrated', 'thoughtfuldemonstrated adaptability', 'adaptability throughout', 'throughout positively', 'positively dealing', 'dealing multiple', 'multiple change', 'change direct', 'direct supervisor', 'supervisor natured', 'natured demeanor', 'demeanor biggesthighly', 'biggesthighly dependable', 'dependable provides', 'provides consistent', 'consistent resultextremely', 'resultextremely reliable', 'reliable dependable', 'dependable punctual', 'punctual professional', 'professional hard', 'hard worker', 'worker ambitious', 'ambitious looking', 'looking maintained', 'maintained highest', 'highest standard', 'standard valuable', 'valuable interndependable', 'interndependable hardeagerness', 'hardeagerness excitement', 'excitement take', 'take new', 'new challenge', 'challenge intellectual', 'intellectual curiosity', 'curiosity master', 'master newly', 'newly introduced', 'introduced topic', 'topic reach', 'reach others', 'others seek', 'seek additionalmotivatedtime', 'additionalmotivatedtime management', 'management us', 'us time', 'time effictively', 'effictively get', 'get assigned', 'assigned accomplish', 'accomplish compiling', 'compiling analyze', 'analyze data', 'data intimate', 'intimate knowledge', 'knowledge microsoft', 'microsoft excel', 'excel othersexceptionally', 'othersexceptionally responsible', 'responsible volunteer', 'volunteer jump', 'jump help', 'help mundane', 'mundane challenging', 'challenging blend', 'blend organized', 'organized oriented', 'oriented style', 'style aforementioned', 'aforementioned sensitivity', 'sensitivity need', 'need whomever', 'whomever assigned', 'assigned compared', 'compared past', 'past exemplified', 'exemplified came', 'came personality', 'personalit ...

# %%
# Count Bigram
bow_14Strength_Bi = Counter(S_Bilist)

# %%
df_14SBi_f = pd.DataFrame(bow_14Strength_Bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
df_14SBi_f
# Out:
#                       word  frequency
# 214            team player         39
# 681      positive attitude         29
# 35           quick learner         29
# 10     communication skill         27
# 245           willing help         22
# ...                    ...        ...
# 3757       process learned          1
# 3758          learned deal          1
# 3759          deal complex          1
# 3760    complex challening          1
# 10541        learn listens          1
#
# [10542 rows x 2 columns]

# %%
# Visualized the bigram
Vsns_14SBi_f = sns.barplot(x = 'frequency', y = 'word', data = df_14SBi_f.head(20))
for i in Vsns_14SBi_f.containers:
    Vsns_14SBi_f.bar_label(i,)
Vsns_14SBi_f.set_title('2014 Strength Bigram', size = 18)
Vsns_14SBi_f.set_xlabel("Frequency", size = 15)
Vsns_14SBi_f.set_ylabel("Word(Bigram)", size = 15)
# Reference:
# [1] https://www.geeksforgeeks.org/how-to-show-values-on-seaborn-barplot/
# [2] https://www.geeksforgeeks.org/change-axis-labels-set-title-and-figure-size-to-plots-with-seaborn/
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
S_Trilist = get_grams(S_Unilist, 3)
print(S_Trilist)
# Out:
# ['ability manage time', 'manage time complete', 'time complete daily', 'complete daily assignment', 'daily assignment detail', 'assignment detail oriented', 'detail oriented extremely', 'oriented extremely organized', 'extremely organized communication', 'organized communication skill', 'communication skill reliable', 'skill reliable individualdemonstrates', 'reliable individualdemonstrates knowledge', 'individualdemonstrates knowledge compiling', 'knowledge compiling analyzing', 'compiling analyzing comparative', 'analyzing comparative report', 'comparative report data', 'report data skill', 'data skill creating', 'skill creating chart', 'creating chart graph', 'chart graph superior', 'graph superior knowledge', 'superior knowledge using', 'knowledge using microsoft', 'using microsoft office', 'microsoft office applicationdetailoriented', 'office applicationdetailoriented customerfocused', 'applicationdetailoriented customerfocused team', 'customerfocused team environmentattention', 'team environmentattention detail', 'environmentattention detail ethic', 'detail ethic quick', 'ethic quick learner', 'quick learner showed', 'learner showed strong', 'showed strong interest', 'strong interest going', 'interest going way', 'going way improve', 'way improve process', 'improve process willingness', 'process willingness learn', 'willingness learn new', 'learn new thingcommunication', 'new thingcommunication skill', 'thingcommunication skill leadership', 'skill leadership lead', 'leadership lead examplemajor', 'lead examplemajor passion', 'examplemajor passion completelythe', 'passion completelythe ability', 'completelythe ability identify', 'ability identify issue', 'identify issue bring', 'issue bring issue', 'bring issue attention', 'issue attention ability', 'attention ability easily', 'ability easily male', 'easily male proceduredone', 'male proceduredone job', 'proceduredone job networking', 'job networking building', 'networking building professional', 'building professional relationship', 'professional relationship outside', 'relationship outside immediate', 'outside immediate team', 'immediate team creative', 'team creative idea', 'creative idea improving', 'idea improving process', 'improving process receptive', 'process receptive feedback', 'receptive feedback asks', 'feedback asks question', 'asks question learn', 'question learn used', 'learn used within', 'used within larger', 'within larger organization', 'larger organization showing', 'organization showing insight', 'showing insight beyond', 'insight beyond scope', 'beyond scope current', 'scope current roledone', 'current roledone lot', 'roledone lot audit', 'lot audit involved', 'audit involved the', 'involved the senior', 'the senior auditor', 'senior auditor transferred', 'auditor transferred allowed', 'transferred allowed john', 'allowed john jump', 'john jump help', 'jump help involved', 'help involved within', 'involved within team', 'within team want', 'team want involved', 'want involved much', 'involved much possible', 'much possible attends', 'possible attends intern', 'attends intern event', 'intern event team', 'event team eventdependable', 'team eventdependable thoughtfuldemonstrated', 'eventdependable thoughtfuldemonstrated adaptability', 'thoughtfuldemonstrated adaptability throughout', 'adaptability throughout positively', 'throughout positively dealing', 'positively dealing multiple', 'dealing multiple change', 'multiple change direct', 'change direct supervisor', 'direct supervisor natured', 'supervisor natured demeanor', 'natured demeanor biggesthighly', 'demeanor biggesthighly dependable', 'biggesthighly dependable provides', 'dependable provides consistent', 'provides consistent resultextremely', 'consistent resultextremely reliable', 'resultextremely reliable dependable', 'reliable dependable punctual', 'dependable punctual professional', 'punctual professional hard', 'professional hard worker', 'hard worker ambitious', 'worker ambitious looking' ...

# %%
bow_14Strength_Tri = Counter(S_Trilist)

# %%
df_14STri_f = pd.DataFrame(bow_14Strength_Tri.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
df_14STri_f
# Out:
#                                           word  frequency
# 1922                         willing learn new          5
# 2869                       afraid ask question          5
# 687                        team player willing          5
# 1212                     problem solving skill          5
# 791                            learn new thing          4
# ...                                        ...        ...
# 4001                  skillcommitted goal time          1
# 4002             goal time managementextremely          1
# 4003       time managementextremely dependable          1
# 4004   managementextremely dependable reliable          1
# 11808                willingness learn listens          1
#
# [11809 rows x 2 columns]

# %%
Vsns_14STri_f = sns.barplot(x = 'frequency', y = 'word', data = df_14STri_f.head(20))
for i in Vsns_14STri_f.containers:
    Vsns_14STri_f.bar_label(i,)
Vsns_14STri_f.set_title('2014 Strength Trigram')
# Out:
# Text(0.5, 1.0, '2014 Strength Trigram')

# %%
df_15B = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/2015-B-EMPFreeResponse.csv")
df_15BE = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/2015-BE-EMPFreeResponse.csv")

# %%
df_15B.rename(columns = {"What are the student's strengths?":'Strengths'}, inplace = True)
df_15BE.rename(columns = {"What are the student's strengths?":'Strengths'}, inplace = True)

# %%
df_15contact = pd.concat([df_15B, df_15BE], axis = 0)

# %%
df_15contact.reset_index(inplace = True, drop = True)

# %%
df_15contact[['Strengths']] = df_15contact[['Strengths']].astype(str)
type(df_15contact['Strengths'])
# Out:
# pandas.core.series.Series

# %%
df_15contact['Strengths'] = df_15contact['Strengths'].apply(lambda x: remove_stopwords(x))

# %%
df_15contact['Strengths'] = df_15contact['Strengths'].apply(lambda x: remove_punctuations(x))

# %%
df_15contact['Strengths'] = df_15contact['Strengths'].str.lower()

# %%
df_15contact['Strengths_tokens'] = df_15contact['Strengths'].apply(lambda x: word_tokens(x))

# %%
df_15contact['Strengths_lem'] = df_15contact['Strengths_tokens'].apply(lambda x: Wnlemm(x))

# %%
df_15contact['Strengths_U'] = df_15contact['Strengths_lem'].apply(lambda x: remove_Uword(x))
df_15contact['Strengths_U']
# Out:
# 0      dedication, understanding, material, could, ef...
# 1      rita, professional, involvement, entire, team,...
# 2      provieding, feedback, following, completing, a...
# 3      1, maturity, 2, self, starter, ability, comple...
# 4      chris, quickly, grasped, difficult, concept, p...
#                              ...
# 694    problem, solver, ingenious, creative, idea, te...
# 695    mathematical, skill, ability, learn, quickly, ...
# 696    hard, worker, assigned, interest, intelligent,...
# 697    organized, self, starter, problem, solver, cre...
# 698                                                  nan
# Name: Strengths_U, Length: 699, dtype: object

# %%
ag_15strength = "".join(df_15contact['Strengths_U'])
words_15strength = word_tokenize(ag_15strength)

# %%
for i in words_15strength[:]:
    if i == ",":
        words_15strength.remove(i)

# %%
bow_15Strength = Counter(words_15strength)
type(bow_15Strength)
# Out:
# collections.Counter

# %%
df_15S_f = pd.DataFrame(bow_15Strength.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V15Sf_Uni = sns.barplot(x = 'frequency', y = 'word', data = df_15S_f.head(20))
for i in V15Sf_Uni.containers:
    V15Sf_Uni.bar_label(i,)
V15Sf_Uni.set_title('2015 Strength Unigram', size = 18)
V15Sf_Uni.set_xlabel("Frequency", size = 15)
V15Sf_Uni.set_ylabel("Word(Unigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Unigram)')

# %%
List15S_Uni = ' '.join([str(item) for item in words_15strength])

# %%
List15S_Bi = get_grams(List15S_Uni, 2)
print(List15S_Bi)
# Out:
# ['dedication understanding', 'understanding material', 'material could', 'could effictively', 'effictively execute', 'execute responsibilityrita', 'responsibilityrita professional', 'professional involvement', 'involvement entire', 'entire team', 'team open', 'open learn', 'learn new', 'new understood', 'understood asked', 'asked take', 'take given', 'given complete', 'complete minimal', 'minimal interaction', 'interaction teamprovieding', 'teamprovieding feedback', 'feedback following', 'following completing', 'completing assigned', 'assigned timely', 'timely manner1', 'manner1 maturity', 'maturity 2', '2 self', 'self starter', 'starter ability', 'ability complete', 'complete without', 'without much', 'much manager', 'manager oversightchris', 'oversightchris quickly', 'quickly grasped', 'grasped difficult', 'difficult concept', 'concept pertaining', 'pertaining pc', 'pc insurance', 'insurance general', 'general chubb', 'chubb ’', '’ structure', 'structure business', 'business process', 'process particular', 'particular prioritized', 'prioritized managed', 'managed time', 'time enabled', 'enabled successfully', 'successfully assist', 'assist several', 'several member', 'member team', 'team team', 'team communicated', 'communicated effectively', 'effectively across', 'across multiple', 'multiple level', 'level audience', 'audience within', 'within department', 'department departmentteamworking', 'departmentteamworking creative', 'creative customer', 'customer service', 'service skill', 'skill personablejake', 'personablejake technical', 'technical skill', 'skill quickly', 'quickly grasp', 'grasp given', 'given documenting', 'documenting process', 'process take', 'take way', 'way group', 'group discussion', 'discussion jake', 'jake interacts', 'interacts team', 'team willing', 'willing provide', 'provide assistance', 'assistance neededelliott', 'neededelliott generally', 'generally inquisitive', 'inquisitive characteristic', 'characteristic useful', 'useful financial', 'financial investigation', 'investigation elliott', 'elliott sociable', 'sociable fit', 'fit office', 'office environmentreliable', 'environmentreliable team', 'team player', 'player creative', 'creative efficientmike', 'efficientmike strong', 'strong ethic', 'ethic hold', 'hold extreme', 'extreme desire', 'desire learn', 'learn help', 'help team', 'team wherever', 'wherever can', 'can mike', 'mike help', 'help assigned', 'assigned team', 'team member', 'member proactively', 'proactively reach', 'reach question', 'question along', 'along way', 'way overall', 'overall positive', 'positive attitude', 'attitude rely', 'rely arrive', 'arrive time', 'time leave', 'leave completedbucket', 'completedbucket ariana', 'ariana 3', '3 key', 'key area', 'area 1', '1 communication', 'communication organization', 'organization maturity', 'maturity communication', 'communication ariana', 'ariana speaks', 'speaks eloquently', 'eloquently phone', 'phone call', 'call email', 'email timely', 'timely response', 'response hit', 'hit key', 'key point', 'point responsible', 'responsible communication', 'communication partner', 'partner medium', 'medium campaign', 'campaign could', 'could trusted', 'trusted relay', 'relay proper', 'proper information', 'information organization', 'organization ariana', 'ariana avid', 'avid note', 'note taker', 'taker need', 'need help', 'help prioritizing', 'prioritizing often', 'often started', 'started asked', 'asked ariana', 'ariana know', 'know thing', 'thing need', 'need followed', 'followed on', 'on meet', 'meet deadline', 'deadline maturity', 'maturity ariana', 'ariana mature', 'mature beyond', 'beyond year', 'year often', 'often reminding', 'reminding college', 'college to', 'to internal', 'internal team', 'team external', 'external partner', 'partner perceived', 'perceived key', 'key player', 'player team', 'team often', 'often come', 'come surprise', 'surprise revealed', 'revealed school', 'school keep', 'keep professional', 'professional manner ...

# %%
bow_15S_Bi = Counter(List15S_Bi)
df_15SBi_f = pd.DataFrame(bow_15S_Bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V15f_Bi = sns.barplot(x = 'frequency', y = 'word', data = df_15SBi_f.head(20))
for i in V15f_Bi.containers:
    V15f_Bi.bar_label(i,)
V15f_Bi.set_title('2015 Strength Bigram', size = 18)
V15f_Bi.set_xlabel("Frequency", size = 15)
V15f_Bi.set_ylabel("Word(Bigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
df_16B_1 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/201615-25-B-EMPFreeResponse.csv")
df_16B_2 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20163545-B-EMPFreeResponse.csv")
df_16BE_1 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/201615-25-BE-EMPFreeResponse.csv")
df_16BE_2 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20163545-BE-EMPFreeResponse.csv")

# %%
df_16BE = pd.concat([df_16BE_1, df_16BE_2], axis = 0)
df_16B = pd.concat([df_16B_1, df_16B_2], axis = 0)
df_16 = pd.concat([df_16B, df_16BE], axis = 0)

# %%
df_16.duplicated().sum()
# Out:
# 0

# %%
df_16.isnull().sum()
# Out:
# Responder ID    0
# Work Terms      0
# College         0
# Major           0
# Conc            0
# Class BOT       0
# Citizenship     0
# Co-op #         0
# Strengths       1
# dtype: int64

# %%
df_16[['Strengths']] = df_16[['Strengths']].astype(str)

# %%
df_16['Strengths'] = df_16['Strengths'].apply(lambda x: remove_stopwords(x))

# %%
df_16
# Out:
#     Responder ID     Work Terms College Major  Conc Class BOT     Citizenship  \
# 0             98  201615-201625       B   FIN  5COP        SR      US Citizen
# 1            105  201615-201625       B  ACCT  5COP        SR      US Citizen
# 2            148  201615-201625       B  GBUS  5COP        JR      US Citizen
# 3            159  201615-201625       B   FIN  5COP        SR      US Citizen
# 4            181  201615-201625       B  MKTG  5COP        JR      US Citizen
# ..           ...            ...     ...   ...   ...       ...             ...
# 30          5087  201635-201645      BE  ECON  5COP        PJ  Non US Citizen
# 31          5593  201645-201645      BE  ECON  5COP        PJ  Non US Citizen
# 32          5115  201635-201645      BE  ECON  5COP        PJ  Non US Citizen
# 33          5126  201635-201645      BE  ECON  5COP        JR  Non US Citizen
# 34          5190  201635-201645      BE  ECON  4COP        SR      US Citizen
#
#    Co-op #                                          Strengths
# 0    Third  Michael enthusiastic responsibilities showed g...
# 1    Third  Andrew added lot value PCM co-op experience. H...
# 2    Third          Nick got along well co-ops friendly team.
# 3    Third  Dave incredibly hard worker, stays motivated p...
# 4    Third  Lauren fantastic ability take asked do, comple...
# ..     ...                                                ...
# 30   First                                         articulate
# 31   First  Resourceful, attentive, willing ask questions....
# 32   First  Kazuka bright, motivated, diligent pleasure wo...
# 33   First        Nausher detailed organized tasks completed.
# 34    Only  Focused, Dependable, Friendly, Flexible, Respo...
#
# [619 rows x 9 columns]

# %%
df_16['Strengths'] = df_16['Strengths'].apply(lambda x: remove_punctuations(x))

# %%
df_16['Strengths'] = df_16['Strengths'].str.lower()

# %%
df_16['Strengths'] = df_16['Strengths'].apply(lambda x: word_tokens(x))

# %%
df_16
# Out:
#     Responder ID     Work Terms College Major  Conc Class BOT     Citizenship  \
# 0             98  201615-201625       B   FIN  5COP        SR      US Citizen
# 1            105  201615-201625       B  ACCT  5COP        SR      US Citizen
# 2            148  201615-201625       B  GBUS  5COP        JR      US Citizen
# 3            159  201615-201625       B   FIN  5COP        SR      US Citizen
# 4            181  201615-201625       B  MKTG  5COP        JR      US Citizen
# ..           ...            ...     ...   ...   ...       ...             ...
# 30          5087  201635-201645      BE  ECON  5COP        PJ  Non US Citizen
# 31          5593  201645-201645      BE  ECON  5COP        PJ  Non US Citizen
# 32          5115  201635-201645      BE  ECON  5COP        PJ  Non US Citizen
# 33          5126  201635-201645      BE  ECON  5COP        JR  Non US Citizen
# 34          5190  201635-201645      BE  ECON  4COP        SR      US Citizen
#
#    Co-op #                                          Strengths
# 0    Third  [michael, enthusiastic, responsibilities, show...
# 1    Third  [andrew, added, lot, value, pcm, coop, experie...
# 2    Third    [nick, got, along, well, coops, friendly, team]
# 3    Third  [dave, incredibly, hard, worker, stays, motiva...
# 4    Third  [lauren, fantastic, ability, take, asked, do, ...
# ..     ...                                                ...
# 30   First                                       [articulate]
# 31   First  [resourceful, attentive, willing, ask, questio...
# 32   First  [kazuka, bright, motivated, diligent, pleasure...
# 33   First   [nausher, detailed, organized, tasks, completed]
# 34    Only  [focused, dependable, friendly, flexible, resp...
#
# [619 rows x 9 columns]

# %%
df_16['Strengths'] = df_16['Strengths'].apply(lambda x: Wnlemm(x))

# %%
df_16['Strengths'] = df_16['Strengths'].apply(lambda x: remove_Uword(x))

# %%
ag_16strength = "".join(df_16['Strengths'])
words_16strength = word_tokenize(ag_16strength)

# %%
for i in words_16strength[:]:
    if i == ",":
        words_16strength.remove(i)

# %%
words_16strength
# Out:
# ['michael',
#  'enthusiastic',
#  'responsibility',
#  'showed',
#  'initiative',
#  'within',
#  'teamandrew',
#  'added',
#  'lot',
#  'value',
#  'pcm',
#  'experience',
#  'quick',
#  'learner',
#  'ownership',
#  'researched',
#  'expanded',
#  'pcms',
#  'capability',
#  'firm',
#  'andrew',
#  'passion',
#  'investment',
#  'bring',
#  'new',
#  'idea',
#  'investment',
#  'management',
#  'teamnick',
#  'got',
#  'along',
#  'friendly',
#  'teamdave',
#  'incredibly',
#  'hard',
#  'worker',
#  'stay',
#  'motivated',
#  'positive',
#  'assigned',
#  'brings',
#  'attitude',
#  'every',
#  'problem',
#  'face',
#  'dave',
#  'demonstrated',
#  'strong',
#  'organizational',
#  'processdriven',
#  'skill',
#  'this',
#  'incredibly',
#  'difficult',
#  'job',
#  'steel',
#  'trap',
#  '12',
#  'different',
#  'people',
#  'asking',
#  'weekly',
#  'basis',
#  'dave',
#  'kept',
#  'head',
#  'water',
#  'completed',
#  'short',
#  'longerterm',
#  'this',
#  'take',
#  'strong',
#  'developed',
#  'timemanagement',
#  'skill',
#  'dave',
#  'showed',
#  'professional',
#  'communication',
#  'skill',
#  'ceo',
#  'spoke',
#  'phone',
#  'withlauren',
#  'fantastic',
#  'ability',
#  'take',
#  'asked',
#  'do',
#  'complete',
#  'quickly',
#  'correctly',
#  'organized',
#  'matterm',
#  'grear',
#  'enthusiastic',
#  'amicable',
#  'person',
#  'high',
#  'intellect',
#  'quickly',
#  'learns',
#  'vital',
#  'problemsolving',
#  'technique',
#  'readily',
#  'applies',
#  'ensure',
#  'positive',
#  'outcome',
#  'exhibit',
#  'proficiency',
#  'adapting',
#  'new',
#  'unknown',
#  'often',
#  'intimidating',
#  'professional',
#  'environment',
#  'the',
#  'assessment',
#  'item',
#  'marked',
#  'not',
#  'm',
#  'grear',
#  'surely',
#  'become',
#  'life',
#  'experience',
#  'deeper',
#  'exposure',
#  'new',
#  'professional',
#  'situation',
#  'challenge',
#  'display',
#  'innate',
#  'desire',
#  'identify',
#  'acquire',
#  'essential',
#  'core',
#  'skillsconcepts',
#  'earnestly',
#  'applies',
#  'learned',
#  'practiceorganization',
#  'verbalize',
#  'issue',
#  'present',
#  'possible',
#  'solutionamy',
#  'demonstrated',
#  'deal',
#  'flexibility',
#  'integrating',
#  'organization',
#  'high',
#  'level',
#  'confidence',
#  'serve',
#  'prepares',
#  'force',
#  'solid',
#  'ethic',
#  'willing',
#  'accept',
#  'assigned•',
#  'kelvin',
#  'completed',
#  'timely',
#  'accurate',
#  'manner',
#  'an',
#  'impressive',
#  'characteristic',
#  'ability',
#  'ask',
#  'thought',
#  'provoking',
#  'question',
#  'rather',
#  'spinning',
#  'wheel',
#  'this',
#  'allowed',
#  'independently',
#  'efficiently',
#  'timely',
#  'manner',
#  '•',
#  'kelvin',
#  'flexibile',
#  'team',
#  'player',
#  'certain',
#  'week',
#  'unsure',
#  'assisting',
#  'making',
#  'binder',
#  'sox',
#  'cycle',
#  'operational',
#  'audit',
#  'kelvin',
#  'took',
#  'stride',
#  'effectively',
#  'completed',
#  'assigned',
#  'without',
#  'complaintchris',
#  'team',
#  'player',
#  'listen',
#  'respond',
#  'constructively',
#  'team',
#  'member',
#  'idea',
#  'in',
#  'addition',
#  'strong',
#  'analytical',
#  'thinker',
#  'approach',
#  'complex',
#  'break',
#  'create',
#  'solution',
#  'example',
#  'given',
#  'creating',
#  'travel',
#  'schedule',
#  'wholesaling',
#  'team',
#  'create',
#  'system',
#  'analyze',
#  'territory',
#  'creatre',
#  'travel',
#  'rotation',
#  'based',
#  'it',
#  'chris',
#  'strong',
#  'time',
#  'management',
#  'weigh',
#  'priority',
#  'done',
#  'meet',
#  'deadlineyu',
#  'ha',
#  'positive',
#  'attitude',
#  'towards',
#  'worker',
#  'coworkersproactive',
#  'dependable',
#  'intellectually',
#  'curious',
#  'business',
#  'need',
#  'technology',
#  'serf',
#  'looked',
#  'enhance',
#  'current',
#  'process',
#  'took',
#  'initiative',
#  'implement',
#  'idea',
#  'improvement',
#  'learned',
#  'past',
#  'mistake',
#  'put',
#  'effort',
#  'correcting',
#  'them',
#  'took',
#  'extra',
#  'responsibilitysidney',
#  'positive',
#  'professional',
#  'ethic',
#  'attitude',
#  'missed',
#  'day',
#  'come',
#  'early',
#  'see',
#  'issue',
#  'finding',
#  'career',
#  'path',
#  'completes',
#  'degreekeegan',
#  'attentive',
#  'detail',
#  'organized',
#  'fast',
#  'producing',
#  'quality',
#  'quick',
#  'learneridentifying',
#  'issue',
#  'resolving',
#  'diligence',
#  'productivity',
#  'easy',
#  'going',
#  'communicatorhaving',
#  'funpunctuality',
#  'willing',
#  'take',
#  'challenge',
#  'eye',
#  'paying',
#  'attention',
#  'detail',
#  'think',
#  'thing',
#  'through',
#  'pick',
#  'new',
#  'thing',
#  'rateamir',
#  'extremely',
#  'fast',
#  'learner',
#  'addition',
#  'accurate',
#  'taught',
#  'respectful',
#  'take',
#  'initiative',
#  'complete',
#  'additional',
#  'duty',
#  'others',
#  'complete',
#  'amir',
#  'formed',
#  'positive',
#  'relationship',
#  'many',
#  'member',
#  'gcc',
#  'despite',
#  'entailing',
#  'technical',
#  'support',
#  'service',
#  'amir',
#  'gone',
#  'beyond',
#  'assist',
#  'department',
#  'technical',
#  'difficulty',
#  'thus',
#  'improved',
#  'vital',
#  'practice',
#  'confident',
#  'amir',
#  'asset',
#  'next',
#  'much',
#  'oneanalytical',
#  'skill',
#  'communicationethic',
#  'strategic',
#  'analysis',
#  'major',
#  'technology',
#  'efficient',
#  'can',
#  'handle',
#  'large',
#  'workloadoverall',
#  'happy',
#  'john',
#  'performance',
#  'over',
#  'duration',
#  'john',
#  'showed',
#  'ambition',
#  'furthering',
#  'development',
#  'constantly',
#  'keeping',
#  'news',
#  'adding',
#  'valuable',
#  'marketinsight',
#  'conversation',
#  'john',
#  'strong',
#  'team',
#  'member',
#  'happy',
#  'assist',
#  'assigned',
#  'actively',
#  'sought',
#  'additional',
#  'way',
#  'assist',
#  'team',
#  'member',
#  'john',
#  'selfless',
#  'supporting',
#  'coworkers',
#  'turning',
#  'looking',
#  'way',
#  'help',
#  'member',
#  'team',
#  'showed',
#  'strong',
#  'ethic',
#  'stay',
#  'usually',
#  'one',
#  'first',
#  'door',
#  'morning',
#  'and',
#  'necessary',
#  'stayed',
#  'late',
#  'hand',
#  'complete',
#  'for',
#  'level',
#  'experience',
#  'felt',
#  'john',
#  'fairly',
#  'strong',
#  'technical',
#  'skill',
#  'still',
#  'use',
#  'refinement',
#  'using',
#  'universal',
#  'platform',
#  'ex',
#  'bloomberg',
#  'excel',
#  'morningstar',
#  'however',
#  'developed',
#  'enough',
#  'time',
#  'begin',
#  'grow',
#  'skillrachael',
#  'hardworking',
#  'analytical',
#  'smart',
#  'friendly',
#  'professional',
#  'overall',
#  'pleasure',
#  'with',
#  'heard',
#  'positive',
#  'thing',
#  'everybody',
#  'across',
#  'team',
#  'workedrob',
#  'displayed',
#  'strong',
#  'willingness',
#  'learn',
#  'ethic',
#  'went',
#  'extra',
#  'mile',
#  'not',
#  'take',
#  'advanced',
#  'documented',
#  'detail',
#  'performed',
#  'assigned',
#  'aid',
#  'transition',
#  'nexttake',
#  'job',
#  'seriously',
#  'proficient',
#  'excelprofessional',
#  'spoken',
#  'individual',
#  'communication',
#  'skill',
#  'robbie',
#  'selfstarter',
#  'efficient',
#  'problem',
#  'solver',
#  'taking',
#  'direction',
#  'learns',
#  'quickly',
#  'can',
#  'trusted',
#  'given',
#  'assignment',
#  'see',
#  'timely',
#  'manner',
#  'finish',
#  'additionally',
#  'received',
#  'many',
#  'review',
#  'robbies',
#  'job',
#  'performance',
#  'worked',
#  'setdata',
#  'analysisparker',
#  'self',
#  'motivated',
#  'parker',
#  'enthusiastically',
#  'accepts',
#  'completes',
#  'assigned',
#  'given',
#  'responsibility',
#  'create',
#  'desk',
#  'procedure',
#  'process',
#  'flow',
#  'multiple',
#  'activity',
#  'division',
#  'given',
#  'inexperience',
#  'business',
#  'desk',
#  'procedure',
#  'written',
#  'manner',
#  'anyone',
#  'could',
#  'follow',
#  'understand',
#  'these',
#  'desk',
#  'procedure',
#  'process',
#  'flow',
#  'reviewed',
#  'senior',
#  'staff',
#  'deemed',
#  'quality',
#  'this',
#  'exactly',
#  'looking',
#  'for',
#  'the',
#  'intention',
#  'person',
#  'could',
#  'pick',
#  'documentation',
#  'perform',
#  'activity',
#  'understand',
#  'why',
#  'furthermore',
#  'would',
#  'understand',
#  'issue',
#  'parker',
#  'involved',
#  'initiative',
#  'required',
#  'investigate',
#  'correct',
#  'data',
#  'multiple',
#  'business',
#  'application',
#  'with',
#  'minimal',
#  'instruction',
#  'parker',
#  'complete',
#  'accurate',
#  'timely',
#  'manner',
#  'parker',
#  'reflects',
#  'ability',
#  'listen',
#  'comprehend',
#  'execute',
#  'instruction',
#  'parker',
#  'mature',
#  'motivated',
#  'want',
#  'get',
#  'education',
#  'possible',
#  'want',
#  'mark',
#  'time',
#  'ha',
#  'multiple',
#  'occasion',
#  'come',
#  'express',
#  'readiness',
#  'accept',
#  'new',
#  'wait',
#  'ask',
#  'complete',
#  'express',
#  'desire',
#  'challenging',
#  'see',
#  'characteristic',
#  'maturity',
#  'strong',
#  'personal',
#  'ethicbrianna',
#  'brings',
#  'freshness',
#  'enthusiasm',
#  'assigned',
#  'given',
#  'responsibility',
#  'create',
#  'desk',
#  'procedure',
#  'process',
#  'flow',
#  'multiple',
#  'activity',
#  'division',
#  'given',
#  'inexperience',
#  'business',
#  'desk',
#  'procedure',
#  'written',
#  'manner',
#  'anyone',
#  'could',
#  'follow',
#  'understand',
#  'these',
#  'desk',
#  'procedure',
#  'process',
#  'flow',
#  'reviewed',
#  'senior',
#  'staff',
#  'deemed',
#  'quality',
#  'this',
#  'exactly',
#  'looking',
#  'for',
#  'the',
#  'intention',
#  'person',
#  'could',
#  'pick',
#  'documentation',
#  'perform',
#  'activity',
#  'understand',
#  'why',
#  'furthermore',
#  'would',
#  'understand',
#  'issue',
#  'brianna',
#  '’',
#  'reflects',
#  'ability',
#  'listen',
#  'comprehend',
#  'execute',
#  'instructionzach',
#  'initiative',
#  'looking',
#  'take',
#  'positive',
#  'attitude',
#  'skill',
#  'related',
#  'different',
#  'microsoft',
#  'tool',
#  'strong',
#  'higher',
#  'many',
#  'others',
#  'teamjosh',
#  'completed',
#  'assignment',
#  'timely',
#  'mannerkatelyn',
#  'became',
#  'company',
#  'worked',
#  'u',
#  'year',
#  'half',
#  'stayed',
#  'parttime',
#  'became',
#  'friend',
#  'u',
#  'this',
#  'speaks',
#  'kind',
#  'person',
#  'is',
#  'extremely',
#  'smart',
#  'think',
#  'quickly',
#  'tough',
#  'situation',
#  'shy',
#  'mind',
#  'sending',
#  'communication',
#  'entire',
#  'firm',
#  'versed',
#  'communication',
#  'skill',
#  'writing',
#  'speaking',
#  'quick',
#  'learner',
#  'advanced',
#  'excel',
#  'application',
#  'mastered',
#  'hris',
#  'system',
#  'best',
#  'kind',
#  'person',
#  'is',
#  'character',
#  'speaks',
#  'volume',
#  'performance',
#  'saying',
#  'something',
#  'exceeded',
#  'expectation',
#  'performanceability',
#  'complete',
#  'go',
#  'beyond',
#  'adding',
#  'additional',
#  'thought',
#  'pertinentjie',
#  'worked',
#  'independently',
#  'assignment',
#  'completed',
#  'appropriately',
#  'timely',
#  'organized',
#  'easily',
#  'followed',
#  'take',
#  'additional',
#  'helping',
#  'team',
#  'meet',
#  'deadlinesimrit',
#  'extremely',
#  'dependable',
#  'diligent',
#  'employee',
#  'produced',
#  'product',
#  'reliable',
#  'generally',
#  'free',
#  'error',
#  'simrit',
#  'cycle',
#  'worked',
#  'extremely',
#  'together',
#  'dividing',
#  'workload',
#  'tackling',
#  'issue',
#  'effective',
#  'efficient',
#  'manneralex',
#  'worked',
#  'efficiently',
#  'complete',
#  'many',
#  'dialy',
#  'willing',
#  'step',
#  'needed',
#  'when',
#  'issue',
#  'transpired',
#  'happened',
#  'frequently',
#  'account',
#  'urgency',
#  'many',
#  'client',
#  'request',
#  'alex',
#  'worked',
#  'problem',
#  'solve',
#  'issue',
#  'made',
#  'sure',
#  'team',
#  'aligned',
#  'willing',
#  'step',
#  'help',
#  'one',
#  'else',
#  'team',
#  'bandwidth',
#  'sotyler',
#  'fear',
#  'getting',
#  'involved',
#  'area',
#  'kept',
#  'leadership',
#  'team',
#  'updated',
#  'progress',
#  'allowed',
#  'u',
#  'properly',
#  'schedule',
#  'next',
#  'assignment',
#  'help',
#  'following',
#  'area',
#  'unsurpassed',
#  'technology',
#  'road',
#  'map',
#  'qa',
#  'testing',
#  'deployment',
#  'presentation',
#  'reporting',
#  'gate',
#  'business',
#  'analystcolin',
#  'addition',
#  'planning',
#  'team',
#  '’',
#  'displayed',
#  'ability',
#  'flexible',
#  'challenging',
#  'fast',
#  'paced',
#  'environment',
#  'adapt',
#  'necessary',
#  'there',
#  'several',
#  'time',
#  'pressure',
#  'succeededpankti',
#  'mature',
#  'age',
#  'experience',
#  'intellegent',
#  'tireless',
#  'worker',
#  'strives',
#  'get',
#  'done',
#  'quickly',
#  'without',
#  'sacrificing',
#  'accuracy',
#  'efficiently',
#  'identifies',
#  'solves',
#  'issue',
#  'proactive',
#  'follows',
#  'management',
#  'status',
#  'assignmentnick',
#  'came',
#  'every',
#  'day',
#  'eagerness',
#  'learn',
#  'grow',
#  'professional',
#  'positive',
#  'attitude',
#  'would',
#  'gladly',
#  'accept',
#  'assigned',
#  'pitch',
#  'others',
#  'groupdependability',
#  'show',
#  'initiative',
#  'professional',
#  'attitudeshowed',
#  'strong',
#  'initiative',
#  'understand',
#  'system',
#  'understand',
#  'issue',
#  'trying',
#  'overcome',
#  'developing',
#  'suggestion',
#  'solution',
#  'issue',
#  'attitude',
#  'learn',
#  'engage',
#  'various',
#  'level',
#  'projectorganization',
#  'analytical',
#  'skill',
#  'communication',
#  'skill',
#  'following',
#  'action',
#  'item',
#  'assignedthomas',
#  'smart',
#  'reliable',
#  'punctual',
#  'easy',
#  'with',
#  'accomodating',
#  'thomas',
#  'asset',
#  'teamcommunication',
#  'relationship',
#  'buildingselina',
#  'pleasure',
#  'office',
#  'time',
#  'dependable',
#  'ready',
#  'give',
#  'smile',
#  'faceability',
#  'multitask',
#  'prepared',
#  ...]

# %%
bow_16Strength = Counter(words_16strength)
df_16S_f = pd.DataFrame(bow_16Strength.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V16f_Uni = sns.barplot(x = 'frequency', y = 'word', data = df_16S_f.head(10))
for i in V16f_Uni.containers:
    V16f_Uni.bar_label(i,)
V16f_Uni.set_title('16 Strength Unigram', size = 18)
V16f_Uni.set_xlabel("Frequency", size = 15)
V16f_Uni.set_ylabel("Word(Unigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Unigram)')

# %%
list16_Uni = ' '.join([str(item) for item in words_16strength])

# %%
list16_Bi = get_grams(list16_Uni, 2)
print(list16_Bi)
# Out:
# ['michael enthusiastic', 'enthusiastic responsibility', 'responsibility showed', 'showed initiative', 'initiative within', 'within teamandrew', 'teamandrew added', 'added lot', 'lot value', 'value pcm', 'pcm experience', 'experience quick', 'quick learner', 'learner ownership', 'ownership researched', 'researched expanded', 'expanded pcms', 'pcms capability', 'capability firm', 'firm andrew', 'andrew passion', 'passion investment', 'investment bring', 'bring new', 'new idea', 'idea investment', 'investment management', 'management teamnick', 'teamnick got', 'got along', 'along friendly', 'friendly teamdave', 'teamdave incredibly', 'incredibly hard', 'hard worker', 'worker stay', 'stay motivated', 'motivated positive', 'positive assigned', 'assigned brings', 'brings attitude', 'attitude every', 'every problem', 'problem face', 'face dave', 'dave demonstrated', 'demonstrated strong', 'strong organizational', 'organizational processdriven', 'processdriven skill', 'skill this', 'this incredibly', 'incredibly difficult', 'difficult job', 'job steel', 'steel trap', 'trap 12', '12 different', 'different people', 'people asking', 'asking weekly', 'weekly basis', 'basis dave', 'dave kept', 'kept head', 'head water', 'water completed', 'completed short', 'short longerterm', 'longerterm this', 'this take', 'take strong', 'strong developed', 'developed timemanagement', 'timemanagement skill', 'skill dave', 'dave showed', 'showed professional', 'professional communication', 'communication skill', 'skill ceo', 'ceo spoke', 'spoke phone', 'phone withlauren', 'withlauren fantastic', 'fantastic ability', 'ability take', 'take asked', 'asked do', 'do complete', 'complete quickly', 'quickly correctly', 'correctly organized', 'organized matterm', 'matterm grear', 'grear enthusiastic', 'enthusiastic amicable', 'amicable person', 'person high', 'high intellect', 'intellect quickly', 'quickly learns', 'learns vital', 'vital problemsolving', 'problemsolving technique', 'technique readily', 'readily applies', 'applies ensure', 'ensure positive', 'positive outcome', 'outcome exhibit', 'exhibit proficiency', 'proficiency adapting', 'adapting new', 'new unknown', 'unknown often', 'often intimidating', 'intimidating professional', 'professional environment', 'environment the', 'the assessment', 'assessment item', 'item marked', 'marked not', 'not m', 'm grear', 'grear surely', 'surely become', 'become life', 'life experience', 'experience deeper', 'deeper exposure', 'exposure new', 'new professional', 'professional situation', 'situation challenge', 'challenge display', 'display innate', 'innate desire', 'desire identify', 'identify acquire', 'acquire essential', 'essential core', 'core skillsconcepts', 'skillsconcepts earnestly', 'earnestly applies', 'applies learned', 'learned practiceorganization', 'practiceorganization verbalize', 'verbalize issue', 'issue present', 'present possible', 'possible solutionamy', 'solutionamy demonstrated', 'demonstrated deal', 'deal flexibility', 'flexibility integrating', 'integrating organization', 'organization high', 'high level', 'level confidence', 'confidence serve', 'serve prepares', 'prepares force', 'force solid', 'solid ethic', 'ethic willing', 'willing accept', 'accept assigned•', 'assigned• kelvin', 'kelvin completed', 'completed timely', 'timely accurate', 'accurate manner', 'manner an', 'an impressive', 'impressive characteristic', 'characteristic ability', 'ability ask', 'ask thought', 'thought provoking', 'provoking question', 'question rather', 'rather spinning', 'spinning wheel', 'wheel this', 'this allowed', 'allowed independently', 'independently efficiently', 'efficiently timely', 'timely manner', 'manner •', '• kelvin', 'kelvin flexibile', 'flexibile team', 'team player', 'player certain', 'certain week', 'week unsure', 'unsure assisting', 'assisting making', 'making binder', 'binder sox', 'sox cycle', 'cycle operational', 'operational audit', 'audit kelvin', 'kelvin took', 'took stride', 'stride e ...

# %%
bow_16Strength_Bi = Counter(list16_Bi)
df_16SBi_f = pd.DataFrame(bow_16Strength_Bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V16f_Bi = sns.barplot(x = 'frequency', y = 'word', data = df_16SBi_f.head(20))
for i in V16f_Bi.containers:
    V16f_Bi.bar_label(i,)
V16f_Bi.set_title('2016 Strength Bigram', size = 18)
V16f_Bi.set_xlabel("Frequency", size = 15)
V16f_Bi.set_ylabel("Word(Bigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
df_17B_1 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20171525-B-EMPFreeResponse.csv")
df_17B_2 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20173545-B- EFR Free Response.csv")
df_17BE_1 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20171525-BE-FW-EFR Free Response.csv")
df_17BE_2 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20173545-BE- EFR Free Response.csv")

# %%
df_17BE = pd.concat([df_17BE_1, df_17BE_2], axis = 0)
df_17B = pd.concat([df_17B_1, df_17B_2], axis = 0)
df_17 = pd.concat([df_17B, df_17BE], axis = 0)

# %%
df_17.reset_index(inplace = True, drop = True)
df_17B.reset_index(inplace = True, drop = True)
df_17BE.reset_index(inplace = True, drop = True)

# %%
df_17.duplicated().sum()
df_17B.duplicated().sum()
df_17BE.duplicated().sum()
# Out:
# 0

# %%
df_17.isnull().sum()
# Out:
# Respondent ID    0
# Work Terms       0
# College          0
# Major            0
# Conc             0
# Class BOT        0
# Citizenship      0
# Co-op #          0
# Strengths        6
# dtype: int64

# %%
df_17[['Strengths']] = df_17[['Strengths']].astype(str)

# %%
df_17['Strengths'] = df_17['Strengths'].apply(lambda x: remove_stopwords(x))

# %%
df_17['Strengths'] = df_17['Strengths'].apply(lambda x: remove_punctuations(x))

# %%
df_17['Strengths'] = df_17['Strengths'].str.lower()

# %%
df_17['Strengths'] = df_17['Strengths'].apply(lambda x: word_tokens(x))

# %%
df_17['Strengths'] = df_17['Strengths'].apply(lambda x: remove_Uword(x))

# %%
ag_17strength = "".join(df_17['Strengths'])
words_17strength = word_tokenize(ag_17strength)

# %%
for i in words_17strength[:]:
    if i == ",":
        words_17strength.remove(i)

# %%
bow_17Strength = Counter(words_17strength)

# %%
df_17S_f = pd.DataFrame(bow_17Strength.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V17f_Uni = sns.barplot(x = 'frequency', y = 'word', data = df_17S_f.head(10))
for i in V17f_Uni.containers:
    V17f_Uni.bar_label(i,)
V17f_Uni.set_title('2017 Strength Unigram', size = 18)
V17f_Uni.set_xlabel("Frequency", size = 15)
V17f_Uni.set_ylabel("Word(Unigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Unigram)')

# %%
list_17Uni = ' '.join([str(item) for item in words_17strength])

# %%
list_17Bi = get_grams(list_17Uni, 2)
list_17Bi
# Out:
# ['over course',
#  'course sachins',
#  'sachins demonstrated',
#  'demonstrated improvement',
#  'improvement certain',
#  'certain rigid',
#  'rigid tasks',
#  'tasks when',
#  'when structured',
#  'structured projects',
#  'projects performed',
#  'performed positive',
#  'positive outlook',
#  'outlook frequently',
#  'frequently solicited',
#  'solicited feedback',
#  'feedback could',
#  'could toward',
#  'toward improving',
#  'improving pleasant',
#  'pleasant with',
#  'with clear',
#  'clear overwhelmed',
#  'overwhelmed job',
#  'job made',
#  'made effort',
#  'effort improve',
#  'improve communicate',
#  'communicate challenges',
#  'challenges rest',
#  'rest teamsteve',
#  'teamsteve dependable',
#  'dependable coworkers',
#  'coworkers steve',
#  'steve focus',
#  'focus taskproject',
#  'taskproject hand',
#  'hand effectivelytaniya',
#  'effectivelytaniya asset',
#  'asset team',
#  'team diligent',
#  'diligent show',
#  'show high',
#  'high levels',
#  'levels professionalism',
#  'professionalism throughout',
#  'throughout time',
#  'time rolemature',
#  'rolemature pleasant',
#  'pleasant interaction',
#  'interaction faimer',
#  'faimer staff',
#  'staff international',
#  'international participantsattitude',
#  'participantsattitude willingness',
#  'willingness learninitiative',
#  'learninitiative dependability',
#  'dependability team',
#  'team player',
#  'player dedicationamir',
#  'dedicationamir fast',
#  'fast learner',
#  'learner comes',
#  'comes solutions',
#  'solutions problems',
#  'problems fits',
#  'fits estee',
#  'estee lauder',
#  'lauder corporate',
#  'corporate environmentsam',
#  'environmentsam asset',
#  'asset complete',
#  'complete assigned',
#  'assigned tasks',
#  'tasks job',
#  'job documenting',
#  'documenting instructions',
#  'instructions new',
#  'new replacechristine',
#  'replacechristine really',
#  'really wanted',
#  'wanted whatever',
#  'whatever could',
#  'could help',
#  'help team',
#  'team out',
#  'out pleasant',
#  'pleasant with',
#  'with ext',
#  'ext es',
#  'es workpapers',
#  'workpapers clean',
#  'clean organizedneil',
#  'organizedneil multi',
#  'multi internship',
#  'internship helped',
#  'helped close',
#  'close shipments',
#  'shipments cpc',
#  'cpc business',
#  'business still',
#  'still executing',
#  'executing role',
#  'role neil',
#  'neil helped',
#  'helped train',
#  'train associates',
#  'associates area',
#  'area applying',
#  'applying invoice',
#  'invoice first',
#  'first cartons',
#  'cartons salon',
#  'salon business',
#  'business this',
#  'this speaks',
#  'speaks volumes',
#  'volumes ability',
#  'ability effectively',
#  'effectively put',
#  'put efforts',
#  'efforts towards',
#  'towards getting',
#  'getting first',
#  'first cartons',
#  'cartons invoices',
#  'invoices adds',
#  'adds customer',
#  'customer service',
#  'service following',
#  'following completion',
#  'completion neils',
#  'neils stayed',
#  'stayed weeks',
#  'weeks train',
#  'train new',
#  'new job',
#  'job training',
#  'training new',
#  'new hire',
#  'hire showed',
#  'showed improvement',
#  'improvement original',
#  'original evaluation',
#  'evaluation helpful',
#  'helpful students',
#  'students developmentability',
#  'developmentability adapt',
#  'adapt given',
#  'given quite',
#  'quite different',
#  'different diverse',
#  'diverse tasks',
#  'tasks easily',
#  'easily adapted',
#  'adapted roles',
#  'roles effectively',
#  'effectively assess',
#  'assess issues',
#  'issues present',
#  'present solutionsrachael',
#  'solutionsrachael fast',
#  'fast learner',
#  'learner in',
#  'in beginning',
#  'beginning progressing',
#  'progressing nicely',
#  'nicely building',
#  'building learned',
#  'learned implemented',
#  'implemented learnings',
#  'learnings projects',
#  'projects rachael',
#  'rachael handles',
#  'handles technical',
#  'technical aspects',
#  'aspects software',
#  'software databases',
#  'databases etckatie',
#  'etckatie continues',
#  'continues exhibit',
#  'exhibit problem',
#  'problem solving',
#  'solving skills',
#  'skills shown',
#  'shown confidence',
#  'confidence trusting',
#  'trusting judgment',
#  'judgment continues',
#  'continues manage',
#  'manage time',
#  'time communicate',
#  'communicate effectivelyjack',
#  'effectivelyjack wonderful',
#  'wonderful person',
#  'person personable',
#  'personable easy',
#  'easy going',
#  'going eager',
#  'eager learn',
#  'learn ability',
#  'ability dive',
#  'dive projects',
#  'projects without',
#  'without lot',
#  'lot direction',
#  'direction willing',
#  'willing ask',
#  'ask clarifying',
#  'clarifying questions',
#  'questions along',
#  'along way',
#  'way astute',
#  'astute intellectually',
#  'intellectually curious',
#  'curious helps',
#  'helps situationshunter',
#  'situationshunter mccann',
#  'mccann advanced',
#  'advanced proficiency',
#  'proficiency communication',
#  'communication within',
#  'within complex',
#  'complex set',
#  'set parameters',
#  'parameters confident',
#  'confident accurately',
#  'accurately identify',
#  'identify problems',
#  'problems appropriately',
#  'appropriately generate',
#  'generate alternatives',
#  'alternatives overall',
#  'overall rose',
#  'rose expectations',
#  'expectations challenge',
#  'challenge setethan',
#  'setethan willing',
#  'willing take',
#  'take challenge',
#  'challenge relatively',
#  'relatively fearless',
#  'fearless approach',
#  'approach learning',
#  'learning quick',
#  'quick learner',
#  'learner adaptable',
#  'adaptable different',
#  'different tasks',
#  'tasks responsible',
#  'responsible for',
#  'for became',
#  'became familiar',
#  'familiar technology',
#  'technology troubleshoot',
#  'troubleshoot issues',
#  'issues errors',
#  'errors came',
#  'came upgrace',
#  'upgrace hardworking',
#  'hardworking thorough',
#  'thorough detailoriented',
#  'detailoriented takes',
#  'takes every',
#  'every enthusiasm',
#  'enthusiasm produces',
#  'produces results',
#  'results grace',
#  'grace skilled',
#  'skilled writer',
#  'writer talent',
#  'talent creativity',
#  'creativity shine',
#  'shine assignments',
#  'assignments particularly',
#  'particularly social',
#  'social mediarattandeep',
#  'mediarattandeep willing',
#  'willing available',
#  'available help',
#  'help polite',
#  'polite respectful',
#  'respectful little',
#  'little shy',
#  'shy helpful',
#  'helpful two',
#  'two coops',
#  'coops e',
#  'e works',
#  'works with',
#  'with understands',
#  'understands technology',
#  'technology picked',
#  'picked many',
#  'many customer',
#  'customer service',
#  'service skillsnanwas',
#  'skillsnanwas issue',
#  'issue tardiness',
#  'tardiness absence',
#  'absence general',
#  'general therefore',
#  'therefore dependable',
#  'dependable integrated',
#  'integrated teamryan',
#  'teamryan behaved',
#  'behaved professional',
#  'professional manner',
#  'manner responsive',
#  'responsive directionhard',
#  'directionhard worker',
#  'worker eager',
#  'eager learn',
#  'learn do',
#  'do can',
#  'can independently',
#  'independently quality',
#  'quality positive',
#  'positive attitude',
#  'attitude blended',
#  'blended team',
#  'team seamlesslytyler',
#  'seamlesslytyler punctual',
#  'punctual intuitive',
#  'intuitive intelligent',
#  'intelligent socially',
#  'socially aware',
#  'aware driven',
#  'driven ideal',
#  'ideal could',
#  'could asked',
#  'asked pleasure',
#  'pleasure witheager',
#  'witheager hard',
#  'hard ethic',
#  'ethic self',
#  'self starterjoann',
#  'starterjoann organized',
#  'organized quick',
#  'quick learner',
#  'learner efficient',
#  'efficient dependable',
#  'dependable joann',
#  'joann pleasant',
#  'pleasant with',
#  'with additional',
#  'additional comments',
#  'comments joann',
#  'joann valuable',
#  'valuable member',
#  'member financial',
#  'financial reporting',
#  'reporting team',
#  'team last',
#  'last six',
#  'six months',
#  'months when',
#  'when came',
#  'came board',
#  'board joann',
#  'joann quickly',
#  'quickly learned',
#  'learned many',
#  'many tasks',
#  'tasks assigned',
#  'assigned showed',
#  'showed competence',
#  'competence went',
#  'went completing',
#  'completing confidence',
#  'confidence efficiency',
#  'efficiency due',
#  'due nature',
#  'nature preparing',
#  'preparing cignas',
#  'cignas form',
#  'form 10k',
#  '10k 10q',
#  '10q corporate',
#  'corporate financial',
#  'financial reporting',
#  'reporting team',
#  'team often',
#  'often intense',
#  'intense time',
#  'time constraints',
#  'constraints deliverables',
#  'deliverables many',
#  'many often',
#  'often joann',
#  'joann stepped',
#  'stepped right',
#  'right assumed',
#  'assumed responsibilities',
#  'responsibilities enthusiasm',
#  'enthusiasm organization',
#  'organization skills',
#  'skills desire',
#  'desire learning',
#  'learning evident',
#  'evident asking',
#  'asking thoughtout',
#  'thoughtout questions',
#  'questions helped',
#  'helped manage',
#  'manage tasks',
#  'tasks quite',
#  'quite effectively',
#  'effectively accuracy',
#  'accuracy utmost',
#  'utmost importance',
#  'importance tasks',
#  'tasks reviewing',
#  'reviewing tieing',
#  'tieing reported',
#  'reported numbers',
#  'numbers reported',
#  'reported public',
#  'public joann',
#  'joann stays',
#  'stays top',
#  'top things',
#  'things pays',
#  'pays attention',
#  'attention details',
#  'details in',
#  'in addition',
#  'addition cignas',
#  'cignas corporate',
#  'corporate results',
#  'results joann',
#  'joann performed',
#  'performed significant',
#  'significant tasks',
#  'tasks excellence',
#  'excellence instrumental',
#  'instrumental bringing',
#  'bringing ledger',
#  'ledger uptodate',
#  'uptodate one',
#  'one cignas',
#  'cignas corporate',
#  'corporate benefit',
#  'benefit plans',
#  'plans quickly',
#  'quickly staying',
#  'staying focused',
#  'focused order',
#  'order meet',
#  'meet certain',
#  'certain deadlines',
#  'deadlines joann',
#  'joann ’',
#  '’ assistance',
#  'assistance monthly',
#  'monthly close',
#  'close international',
#  'international division',
#  'division valuable',
#  'valuable ensuring',
#  'ensuring corporate',
#  'corporate expense',
#  'expense summary',
#  'summary various',
#  'various countries',
#  'countries updated',
#  'updated timely',
#  'timely meet',
#  'meet monthly',
#  'monthly deadline',
#  'deadline in',
#  'in addition',
#  'addition joann',
#  'joann worked',
#  'worked cignas',
#  'cignas corporate',
#  'corporate sox',
#  'sox team',
#  'team monitoring',
#  'monitoring quarterly',
#  'quarterly certification',
#  'certification process',
#  'process special',
#  'special projects',
#  'projects related',
#  'related soxrelated',
#  'soxrelated controls',
#  'controls play',
#  'play important',
#  'important aspect',
#  'aspect company',
#  'company ’',
#  '’ financial',
#  'financial integrity',
#  'integrity proactive',
#  'proactive following',
#  'following issues',
#  'issues productivity',
#  'productivity diligence',
#  'diligence items',
#  'items noteworthy',
#  'noteworthy laudatory',
#  'laudatory joann',
#  'joann important',
#  'important partner',
#  'partner helping',
#  'helping manager',
#  'manager developing',
#  'developing carrying',
#  'carrying programs',
#  'programs initiatives',
#  'initiatives students',
#  'students cigna',
#  'cigna being',
#  'being connected',
#  'connected things',
#  'things together',
#  'together workplace',
#  'workplace important',
#  'important element',
#  'element experience',
#  'experience students',
#  'students company',
#  'company joann',
#  'joann helped',
#  'helped bring',
#  'bring students',
#  'students together',
#  'together scheduling',
#  'scheduling events',
#  'events students',
#  'students making',
#  'making sure',
#  'sure made',
#  'made aware',
#  'aware upcoming',
#  'upcoming events',
#  'events leadership',
#  'leadership skills',
#  'skills evident',
#  'evident inaugural',
#  'inaugural issues',
#  'issues cigna',
#  'cigna coops',
#  'coops newsletter',
#  'newsletter became',
#  'became reality',
#  'reality mainly',
#  'mainly due',
#  'due joann',
#  'joann ’',
#  '’ tireless',
#  'tireless efforts',
#  'efforts artful',
#  'artful imagination',
#  'imagination we',
#  'we pleased',
#  'pleased joann',
#  'joann ’',
#  '’ diligence',
#  'diligence contributions',
#  'contributions corporate',
#  'corporate accounting',
#  'accounting department',
#  'department ethics',
#  'ethics strong',
#  'strong commitment',
#  'commitment learning',
#  'learning aided',
#  'aided experience',
#  'experience excels',
#  'excels juggling',
#  'juggling variety',
#  'variety concurrent',
#  'concurrent tasks',
#  'tasks especially',
#  'especially busy',
#  'busy times',
#  'times dependable',
#  'dependable managers',
#  'managers confidence',
#  'confidence assigning',
#  'assigning knowing',
#  'knowing would',
#  'would completed',
#  'completed accurately',
#  'accurately timely',
#  'timely professional',
#  'professional manner',
#  'manner as',
#  'as manager',
#  'manager appreciative',
#  'appreciative commitment',
#  'commitment assistance',
#  'assistance financial',
#  'financial reporting',
#  'reporting role',
#  'role cigna',
#  'cigna programs',
#  'programs activitiesthe',
#  'activitiesthe strong',
#  'strong ethiclenni',
#  'ethiclenni proven',
#  'proven valuable',
#  'valuable asset',
#  'asset social',
#  'social strategy',
#  'strategy team',
#  'team unique',
#  'unique ability',
#  'ability hit',
#  'hit ground',
#  'ground running',
#  'running contribute',
#  'contribute greatly',
#  'greatly exceptional',
#  'exceptional asking',
#  'asking important',
#  'important questions',
#  'questions aptitude',
#  'aptitude understanding',
#  'understanding processes',
#  'processes around',
#  'around shown',
#  'shown extraordinary',
#  'extraordinary willingness',
#  'willingness learn',
#  'learn contribute',
#  'contribute team',
#  'team way',
#  'way possible',
#  'possible regularly',
#  'regularly reaching',
#  'reaching team',
#  'team memebers',
#  'memebers asking',
#  'asking help',
#  'help excelled',
#  'excelled assigned',
#  'assigned tasks',
#  'tasks shows',
#  'shows positive',
#  'positive attitudeleslie',
#  'attitudeleslie worked',
#  'worked members',
#  'members staff',
#  'staff courteous',
#  'courteous took',
#  'took initiatives',
#  'initiatives ran',
#  'ran themchristine',
#  'themchristine keen',
#  'keen analytical',
#  'analytical mind',
#  'mind sense',
#  'sense purpose',
#  'purpose fantastic',
#  'fantastic team',
#  'team player',
#  'player works',
#  'works diligently',
#  'diligently make',
#  'make sure',
#  'sure high',
#  'high qualityunable',
#  'qualityunable identify',
#  'identify strengths',
#  'strengths tarik',
#  'tarik engaging',
#  'engaging multiple',
#  'multiple conversations',
#  'conversations regarding',
#  'regarding goals',
#  'goals tasks',
#  'tasks idea',
#  'idea understood',
#  'understood assignment',
#  'assignment receive',
#  'receive feedback',
#  'feedback engage',
#  'engage conversation',
#  'conversation get',
#  'get detailsorganized',
#  'detailsorganized reliable',
#  'reliable dependableziqui',
#  'dependableziqui punctual',
#  'punctual asks',
#  'asks appropriate',
#  'appropriate questions',
#  'questions needs',
#  'needs helpmichael',
#  'helpmichael smart',
#  'smart analytical',
#  'analytical skills',
#  'skills expresses',
#  'expresses ideas',
#  'ideas thoughts',
#  'thoughts clearly',
#  'clearly shows',
#  'shows openness',
#  'openness learn',
#  'learn othersintegrated',
#  'othersintegrated team',
#  'team fast',
#  'fast learner',
#  'learner looking',
#  'looking opportunities',
#  'opportunities help',
#  'help group',
#  'group projectsinitiativesmorgans',
#  'projectsinitiativesmorgans key',
#  'key strengths',
#  'strengths time',
#  'time management',
#  'management communication',
#  'communication teammates',
#  'teammates business',
#  'business representatives',
#  'representatives creative',
#  'creative writing',
#  'writing networking',
#  'networking we',
#  'we complete',
#  'complete confidence',
#  'confidence ability',
#  'ability perform',
#  'perform receiving',
#  'receiving initial',
#  'initial assignments',
#  'assignments direction',
#  'direction often',
#  'often took',
#  'took initiative',
#  'initiative ensure',
#  'ensure projects',
#  'projects completed',
#  'completed according',
#  'according corporate',
#  'corporate brand',
#  'brand standards',
#  'standards afraid',
#  'afraid ask',
#  'ask questions',
#  'questions confirm',
#  'confirm meeting',
#  'meeting expectations',
#  'expectations in',
#  'in weekly',
#  'weekly 1x1',
#  '1x1 meetings',
#  'meetings came',
#  'came prepared',
#  'prepared wellorganized',
#  'wellorganized agenda',
#  'agenda list',
#  'list open',
#  'open items',
#  'items hoped',
#  'hoped resolve',
#  'resolve with',
#  'with assistance',
#  'assistance successfully',
#  'successfully onboard',
#  'onboard new',
#  'new pr',
#  'pr agency',
#  'agency partner',
#  'partner develop',
#  'develop effective',
#  'effective tracking',
#  'tracking system',
#  'system earned',
#  'earned media',
#  'media placements',
#  'placements accepted',
#  'accepted challenging',
#  'challenging assignments',
#  'assignments including',
#  'including coordination',
#  'coordination america',
#  'america saves',
#  'saves week',
#  'week marketing',
#  'marketing campaign',
#  'campaign grace',
#  'grace confidence',
#  'confidence offered',
#  'offered creative',
#  'creative suggestions',
#  'suggestions change',
#  'change approach',
#  'approach morgan',
#  'morgan proved',
#  'proved networker',
#  'networker forming',
#  'forming relationships',
#  'relationships associates',
#  'associates across',
#  'across different',
#  'different internal',
#  'internal departments',
#  'departments liaison',
#  'liaison activities',
#  'activities committee',
#  'committee gained',
#  'gained firsthand',
#  'firsthand experience',
#  'experience presenting',
#  'presenting executives',
#  'executives walked',
#  'walked campaign',
#  'campaign proposal',
#  'proposal rick',
#  'rick iraces',
#  'iraces staff',
#  'staff meeting',
#  'meeting it',
#  'it evident',
#  'evident done',
#  'done preparation',
#  'preparation needed',
#  'needed ensure',
#  'ensure ready',
#  'ready presentation',
#  'presentation many',
#  'many executives',
#  'executives leaders',
#  'leaders later',
#  'later commented',
#  'commented presented',
#  'presented ideas',
#  'ideas morgan',
#  'morgan enabled',
#  'enabled mentor',
#  'mentor streamline',
#  'streamline number',
#  'number processes',
#  'processes related',
#  'related management',
#  'management public',
#  'public relations',
#  'relations program',
#  'program including',
#  'including media',
#  'media pitching',
#  'pitching reporting',
#  'reporting publishing',
#  'publishing im',
#  'im extremely',
#  'extremely grateful',
#  'grateful matched',
#  'matched morgan',
#  'morgan cycle',
#  'cycle look',
#  'look forward',
#  'forward next',
#  'next months',
#  'months begins',
#  'begins parttime',
#  'parttime teamcam',
#  'teamcam committed',
#  'committed level',
#  'level headed',
#  'headed technical',
#  'technical background',
#  'background nicely',
#  'nicely blend',
#  'blend technical',
#  'technical business',
#  'business aspects',
#  'aspects background',
#  'background education',
#  'education product',
#  'product rolekai',
#  'rolekai smart',
#  'smart technology',
#  'technology research',
#  'research problem',
#  'problem solver',
#  'solver utilizes',
#  'utilizes technology',
#  'technology learn',
#  'learn things',
#  'things understandorganization',
#  'understandorganization analytical',
#  'analytical skills',
#  'skills written',
#  'written communication',
#  'communication skillsjen',
#  'skillsjen incredibly',
#  'incredibly hard',
#  'hard worker',
#  'worker time',
#  'time went',
#  'went beyond',
#  'beyond every',
#  'every single',
#  'single could',
#  'could rely',
#  'rely complete',
#  'complete job',
#  'job time',
#  'time due',
#  'due later',
#  'later created',
#  'created lot',
#  'lot new',
#  'new literature',
#  'literature materials',
#  'materials office',
#  'office given',
#  'given free',
#  'free range',
#  'range creativity',
#  'creativity used',
#  'used resources',
#  'resources complete',
#  'complete projects',
#  'projects without',
#  'without rely',
#  'rely others',
#  'others much',
#  'much help',
#  'help jen',
#  'jen professional',
#  'professional helpful',
#  'helpful training',
#  'training needed',
#  'needed new',
#  'new real',
#  'real estate',
#  'estate agentsharry',
#  'agentsharry possitive',
#  'possitive attitude',
#  'attitude nice',
#  'nice talk',
#  'talk with',
#  'with upbeat',
#  'upbeat smilingeva',
#  'smilingeva dependable',
#  'dependable hardworking',
#  'hardworking looking',
#  'looking learn',
#  'learn find',
#  'find ways',
#  'ways grow',
#  'grow within',
#  'within role',
#  'role handle',
#  'handle many',
#  'many tasks',
#  'tasks given',
#  'given once',
#  'once prioritize',
#  'prioritize critical',
#  'critical tasks',
#  'tasks done',
#  'done appropriately',
#  'appropriately maintaining',
#  'maintaining high',
#  'high quality',
#  'quality eva',
#  'eva asset',
#  'asset team',
#  'team time',
#  'time usjake',
#  'usjake agile',
#  'agile selfmotivated',
#  'selfmotivated learner',
#  'learner assess',
#  'assess develop',
#  'develop strategy',
#  'strategy complete',
#  'complete assigned',
#  'assigned tasks',
#  'tasks interning',
#  'interning us',
#  'us took',
#  'took initiative',
#  'initiative research',
#  'research options',
#  'options process',
#  'process improvements',
#  'improvements identify',
#  'identify requirements',
#  'requirements suggest',
#  'suggest implement',
#  'implement solutions',
#  'solutions verbal',
#  'verbal communication',
#  'communication skills',
#  'skills interact',
#  'interact levels',
#  'levels management',
#  'management colleaguesfinn',
#  'colleaguesfinn handle',
#  'handle multiple',
#  'multiple jobs',
#  'jobs time',
#  'time see',
#  ...]

# %%
bow_17Strength_Bi = Counter(list_17Bi)
df_17SBi_f = pd.DataFrame(bow_17Strength_Bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V17f_Bi = sns.barplot(x = 'frequency', y = 'word', data = df_17SBi_f.head(20))
for i in V17f_Bi.containers:
    V17f_Bi.bar_label(i,)
V17f_Bi.set_title('2017 Strength Bigram', size = 18)
V17f_Bi.set_xlabel("Frequency", size = 15)
V17f_Bi.set_ylabel("Word(Bigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
df_18B = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20181525-B-FW-EMPFreeResponse.csv")
df_18BE = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/20181525-BE-FW-EMPFreeResponse.csv")

# %%
df_18 = pd.concat([df_18B, df_18BE], axis = 0)

# %%
df_18.reset_index(inplace = True, drop = True)

# %%
df_18.duplicated().sum()
# Out:
# 0

# %%
df_18.isnull().sum()
# Out:
# Respondent ID    0
# Work Terms       0
# College          0
# Major            0
# Conc             0
# Class BOT        0
# Citizenship      0
# Co-op #          0
# Strengths        2
# dtype: int64

# %%
df_18[['Strengths']] = df_18[['Strengths']].astype(str)

# %%
df_18['Strengths'] = df_18['Strengths'].apply(lambda x: remove_stopwords(x))

# %%
df_18['Strengths'] = df_18['Strengths'].apply(lambda x: remove_punctuations(x))

# %%
df_18['Strengths'] = df_18['Strengths'].str.lower()

# %%
df_18['Strengths'] = df_18['Strengths'].apply(lambda x: word_tokens(x))

# %%
df_18['Strengths'] = df_18['Strengths'].apply(lambda x: Wnlemm(x))

# %%
df_18['Strengths'] = df_18['Strengths'].apply(lambda x: remove_Uword(x))

# %%
ag_18strength = "".join(df_18['Strengths'])
words_18strength = word_tokenize(ag_18strength)

# %%
for i in words_18strength[:]:
    if i == ",":
        words_18strength.remove(i)

# %%
list_18Uni = ' '.join([str(item) for item in words_18strength])

# %%
list_18Bi = get_grams(list_18Uni, 2)

# %%
bow_18Strength_Bi = Counter(list_18Bi)

# %%
df_18SBi_f = pd.DataFrame(bow_18Strength_Bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V18f_Bi = sns.barplot(x = 'frequency', y = 'word', data = df_18SBi_f.head(20))
for i in V18f_Bi.containers:
    V18f_Bi.bar_label(i,)
V18f_Bi.set_title('2018 Strength Bigram', size = 18)
V18f_Bi.set_xlabel("Frequency", size = 15)
V18f_Bi.set_ylabel("Word(Bigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
df_19= pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/AY 2019-BBE-EMPFreeResponse.csv")

# %%
df_19.duplicated().sum()
# Out:
# 0

# %%
df_19.isnull().sum()
# Out:
# Respondent ID    0
# Work Terms       0
# College          0
# Major            0
# Conc             0
# Class BOT        0
# Citizenship      0
# Co-op #          0
# Strengths        2
# dtype: int64

# %%
df_19[['Strengths']] = df_19[['Strengths']].astype(str)

# %%
df_19['Strengths'] = df_19['Strengths'].apply(lambda x: remove_stopwords(x))

# %%
df_19['Strengths'] = df_19['Strengths'].apply(lambda x: remove_punctuations(x))

# %%
df_19['Strengths'] = df_19['Strengths'].str.lower()

# %%
df_19['Strengths'] = df_19['Strengths'].apply(lambda x: word_tokens(x))

# %%
df_19['Strengths'] = df_19['Strengths'].apply(lambda x: Wnlemm(x))

# %%
df_19['Strengths'] = df_19['Strengths'].apply(lambda x: remove_Uword(x))

# %%
ag_19strength = "".join(df_19['Strengths'])
words_19strength = word_tokenize(ag_19strength)

# %%
for i in words_19strength[:]:
    if i == ",":
        words_19strength.remove(i)

# %%
list_19Uni = ' '.join([str(item) for item in words_19strength])

# %%
list_19Bi = get_grams(list_19Uni, 2)

# %%
bow_19Strength = Counter(list_19Bi)

# %%
df_19S_f = pd.DataFrame(bow_19Strength.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V19f_Bi = sns.barplot(x = 'frequency', y = 'word', data = df_19S_f.head(20))
for i in V19f_Bi.containers:
    V19f_Bi.bar_label(i,)
V19f_Bi.set_title('2019 Strength Bigram', size = 18)
V19f_Bi.set_xlabel("Frequency", size = 15)
V19f_Bi.set_ylabel("Word(Bigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
df_20 = pd.read_csv("D:/Master Courses/22 Fall Quarter/MIS 612/Group Project Final/Usable Data/AY 2020-BBE-EMP Free Response.csv")

# %%
df_20.duplicated().sum()
# Out:
# 0

# %%
df_20.isnull().sum()
# Out:
# Respondent ID    0
# Work Terms       0
# College          0
# Major            0
# Conc             0
# Class BOT        0
# Citizenship      0
# Co-op #          0
# Strengths        1
# dtype: int64

# %%
df_20[['Strengths']] = df_20[['Strengths']].astype(str)

# %%
df_20['Strengths'] = df_20['Strengths'].apply(lambda x: remove_stopwords(x))

# %%
df_20['Strengths'] = df_20['Strengths'].apply(lambda x: remove_punctuations(x))

# %%
df_20['Strengths'] = df_20['Strengths'].str.lower()

# %%
df_20['Strengths'] = df_20['Strengths'].apply(lambda x: word_tokens(x))

# %%
df_20['Strengths'] = df_20['Strengths'].apply(lambda x: Wnlemm(x))

# %%
df_20['Strengths'] = df_20['Strengths'].apply(lambda x: remove_Uword(x))
df_20
# Out:
#      Respondent ID     Work Terms College Major  Conc Class BOT  \
# 0             2181  Spring/Summer       B  ACCT  5COP        SR
# 1               74    Fall/Winter       B   MIS  5COP        SR
# 2             5586  Spring/Summer       B   FIN  5COP        SR
# 3             2366  Spring/Summer       B   FIN  5COP        SR
# 4             2367  Spring/Summer       B  MKTG  5COP        SR
# ..             ...            ...     ...   ...   ...       ...
# 701           5558  Spring/Summer       B   FIN  4COP        SR
# 702           5562  Spring/Summer       B  MKTG  5COP        JR
# 703           5912  Spring/Summer       B   FIN  5COP        PJ
# 704           5572  Spring/Summer       B  ACCT  5COP        JR
# 705           5574  Spring/Summer       B   FIN  5COP        PJ
#
#        Citizenship      Co-op #  \
# 0         Domestic  Third/Final
# 1         Domestic  Third/Final
# 2         Domestic       Second
# 3         Domestic  Third/Final
# 4         Domestic  Third/Final
# ..             ...          ...
# 701       Domestic        First
# 702  International        First
# 703       Domestic        First
# 704  International        First
# 705       Domestic        First
#
#                                              Strengths
# 0                   asks, question, positive, attitude
# 1            number, based, analytics, advanced, excel
# 2    christina, organized, focused, accepts, feedba...
# 3    justin, pick, process, quickly, efficiently, c...
# 4    alessandra, wonderful, attitude, highly, profe...
# ..                                                 ...
# 701            successfully, take, new, solve, problem
# 702  nhi, effective, analyzing, data, using, variet...
# 703  willie, polite, willing, listen, follows, dire...
# 704  munira, fantastic, asset, finance, team, detai...
# 705  a, ppl, person, quick, learner, adaptive, new,...
#
# [706 rows x 9 columns]

# %%
ag_20strength = "".join(df_20['Strengths'])
words_20strength = word_tokenize(ag_20strength)

# %%
for i in words_20strength[:]:
    if i == ",":
        words_20strength.remove(i)

# %%
list_20Uni = ' '.join([str(item) for item in words_20strength])

# %%
list_20Bi = get_grams(list_20Uni, 2)

# %%
bow_20Strength = Counter(list_20Bi)

# %%
df_20S_f = pd.DataFrame(bow_20Strength.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V20f_Bi = sns.barplot(x = 'frequency', y = 'word', data = df_20S_f.head(20))
for i in V20f_Bi.containers:
    V20f_Bi.bar_label(i,)
V20f_Bi.set_title('2020 Strength Bigram', size = 18)
V20f_Bi.set_xlabel("Frequency", size = 15)
V20f_Bi.set_ylabel("Word(Bigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
df_14SBi_f.head(20)
# Out:
#                      word  frequency
# 214           team player         39
# 681     positive attitude         29
# 35          quick learner         29
# 10    communication skill         27
# 245          willing help         22
# 1564        timely manner         21
# 1292     attention detail         19
# 1895      time management         17
# 221           eager learn         16
# 2125      take initiative         13
# 134           hard worker         13
# 385          willing take         13
# 6         detail oriented         13
# 45              learn new         13
# 242           team member         13
# 145              take new         12
# 78          asks question         12
# 774             new thing         11
# 5231            get along         11
# 2285         ask question         11

# %%
df_14SBi_f['word']
# Out:
# 214              team player
# 681        positive attitude
# 35             quick learner
# 10       communication skill
# 245             willing help
#                 ...
# 3757         process learned
# 3758            learned deal
# 3759            deal complex
# 3760      complex challening
# 10541          learn listens
# Name: word, Length: 10542, dtype: object

# %%
print(df_14SBi_f.iloc[:21,0])
# Out:
# 214             team player
# 681       positive attitude
# 35            quick learner
# 10      communication skill
# 245            willing help
# 1564          timely manner
# 1292       attention detail
# 1895        time management
# 221             eager learn
# 2125        take initiative
# 134             hard worker
# 385            willing take
# 6           detail oriented
# 45                learn new
# 242             team member
# 145                take new
# 78            asks question
# 774               new thing
# 5231              get along
# 2285           ask question
# 516        attitude willing
# Name: word, dtype: object

# %%
print(df_15SBi_f.iloc[:21,0])
# Out:
# 105             team player
# 130       positive attitude
# 219             eager learn
# 513        attention detail
# 12                learn new
# 308           quick learner
# 1467        time management
# 471     communication skill
# 892             hard worker
# 454            ask question
# 1794              get along
# 1180          timely manner
# 122             team member
# 808       willingness learn
# 1437        problem solving
# 666            willing help
# 2194           willing take
# 676           asks question
# 216              afraid ask
# 59              member team
# 1967        ability quickly
# Name: word, dtype: object

# %%
df_14_20 = pd.concat([df_preproce['Strengths_U'], df_15contact['Strengths_U'], df_16['Strengths'], df_17['Strengths'], df_18['Strengths'], df_19['Strengths'], df_20['Strengths']], axis = 0)

# %%
df_14_20
# Out:
# 0      ability, manage, time, complete, daily, assign...
# 1      demonstrates, knowledge, compiling, analyzing,...
# 2      detailoriented, customerfocused, team, environ...
# 3      attention, detail, ethic, quick, learner, show...
# 4        communication, skill, leadership, lead, example
#                              ...
# 701              successfully, take, new, solve, problem
# 702    nhi, effective, analyzing, data, using, variet...
# 703    willie, polite, willing, listen, follows, dire...
# 704    munira, fantastic, asset, finance, team, detai...
# 705    a, ppl, person, quick, learner, adaptive, new,...
# Length: 4374, dtype: object

# %%
ag_14_20strength = "".join(df_14_20)
words_14_20strength = word_tokenize(ag_14_20strength)

# %%
for i in words_14_20strength[:]:
    if i == ",":
        words_14_20strength.remove(i)

# %%
list_14_20Uni = ' '.join([str(item) for item in words_14_20strength])

# %%
list_14_20Bi = get_grams(list_14_20Uni, 2)

# %%
bow_14_20Strength = Counter(list_14_20Bi)

# %%
df_1420S_f = pd.DataFrame(bow_14_20Strength.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
V1420f_Bi = sns.barplot(x = 'frequency', y = 'word', data = df_1420S_f.head(10))
V1420f_Bi.set_title('2014—2020 Strength Bigram', size = 18)
V1420f_Bi.set_xlabel("Frequency", size = 15)
V1420f_Bi.set_ylabel("Word(Bigram)", size = 15)
# Out:
# Text(0, 0.5, 'Word(Bigram)')

# %%
df_1420S_f
# Out:
#                        word  frequency
# 0               team player        177
# 1         positive attitude        177
# 2             quick learner        133
# 3          attention detail        131
# 4               eager learn        121
# ...                     ...        ...
# 60262         detail proven          1
# 60263           became high          1
# 60264      high functioning          1
# 60265    functioning member          1
# 60266  counterpart reliable          1
#
# [60267 rows x 2 columns]

# %%
df_20S_f.head(20)
# Out:
#                       word  frequency
# 67             team player         33
# 109          quick learner         22
# 1104     positive attitude         22
# 961            eager learn         19
# 614           ask question         18
# 1064           team member         17
# 205        take initiative         17
# 38     communication skill         15
# 971       attention detail         14
# 545      willingness learn         12
# 184            in addition         12
# 2161           hard worker         12
# 718              learn new         12
# 1948       time management         11
# 1905             new thing         11
# 736   strong communication         11
# 142          timely manner         11
# 42            willing take         10
# 1904          learning new         10
# 75           social medium         10

# %%
df_1420S_f.reset_index(inplace = True, drop = True)
df_1420S_f
# Out:
#                        word  frequency
# 0               team player        177
# 1         positive attitude        177
# 2             quick learner        133
# 3          attention detail        131
# 4               eager learn        121
# ...                     ...        ...
# 60262         detail proven          1
# 60263           became high          1
# 60264      high functioning          1
# 60265    functioning member          1
# 60266  counterpart reliable          1
#
# [60267 rows x 2 columns]

# %%
df_17SBi_f
# Out:
#                        word  frequency
# 58              team player         30
# 196             eager learn         26
# 313       positive attitude         26
# 1785           team members         23
# 242           quick learner         23
# ...                     ...        ...
# 3938              hand when          1
# 3940         assigned would          1
# 3941              would put          1
# 3942               put head          1
# 11003  constant supervision          1
#
# [11004 rows x 2 columns]

# %%
df_18SBi_f
# Out:
#                     word  frequency
# 40      attention detail         21
# 73     positive attitude         16
# 1444        willing take         14
# 1786           learn new         12
# 324          hard worker         12
# ...                  ...        ...
# 2257        stepped team          1
# 2256  transition stepped          1
# 2255     time transition          1
# 2254         worked time          1
# 6413          real added          1
#
# [6414 rows x 2 columns]

# %%
df_19S_f
# Out:
#                            word  frequency
# 264           positive attitude         25
# 9           communication skill         24
# 351             take initiative         18
# 93                  hard worker         18
# 118               quick learner         18
# ...                         ...        ...
# 3466               ability many          1
# 3467         many differentjohn          1
# 3468      differentjohn willing          1
# 3469  willing hardworkermalaika          1
# 9750             actually apply          1
#
# [9751 rows x 2 columns]

# %%
df_20S_f
# Out:
#                                word  frequency
# 67                      team player         33
# 109                   quick learner         22
# 1104              positive attitude         22
# 961                     eager learn         19
# 614                    ask question         18
# ...                             ...        ...
# 3905                writing ability          1
# 3906               ability analysis          1
# 3907             analysis difficult          1
# 3908   difficult situationproactive          1
# 10841          counterpart reliable          1
#
# [10842 rows x 2 columns]

# %%
## Acknowledgments: 
# Codes are completed by Ruifeng Wang, since I am new to Python programming, I refer to Yamini(Group leader), CSDN, Jianshu, geeksforgeeks, stackoverflow. Reference links are posted as comments when I refered for the first time, thank you for their help.
